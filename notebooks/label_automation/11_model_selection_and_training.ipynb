# %%
#import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# For modeling later
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, precision_score, recall_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier


#commands for better readability 
pd.set_option('display.max_colwidth', None)  # show full content in each column
pd.set_option('display.max_columns', None)   # show all columns
pd.set_option('display.width', 2000)         # widen the display to avoid wrapping

pd.set_option('display.max_columns', None)  #display all columns 
pd.set_option('display.max_rows', None)  #display all rows 
warnings.filterwarnings("ignore", category=UserWarning, module='pandas')  #surpress warning messages

# %%
#import csv file and convert it to dataframe


file_path_full='/Users/India/Documents/match_names/df_full.csv'  #replace with respective file path 
df_full=pd.read_csv(file_path_full)  #specify delimiters to avoid reading errors

file_path_labelled='/Users/India/Documents/match_names/training_data.csv'  #replace with respective file path 
df_label=pd.read_csv(file_path_labelled)  #specify delimiters to avoid reading errors

# %%
df_full.drop(columns=['cap_rule_applied','num_matched_tokens'], inplace=True)
df_label.drop(columns=['cap_rule_applied','num_matched_tokens'], inplace=True)

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3608 entries, 0 to 3607
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   uk_id                     3608 non-null   int64
#  1   uk_name                   3608 non-null   object
#  2   eu_id                     3608 non-null   int64
#  3   eu_name                   3608 non-null   object
#  4   final_multi_score         3608 non-null   int64
#  5   avg_adjusted_token_score  3608 non-null   float64
#  6   jaccard_similarity        3608 non-null   float64
#  7   overlap_count             3608 non-null   int64
#  8   min_token_len_matched     3608 non-null   int64
#  9   max_token_len_matched     3608 non-null   int64
#  10  mean_token_len_matched    3608 non-null   float64
#  11  num_uk_tokens             3608 non-null   int64
#  12  num_eu_tokens             3608 non-null   int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 366.6+ KB

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   uk_id                     385 non-null    int64
#  1   uk_name                   385 non-null    object
#  2   eu_id                     385 non-null    int64
#  3   eu_name                   385 non-null    object
#  4   final_multi_score         385 non-null    int64
#  5   avg_adjusted_token_score  385 non-null    float64
#  6   jaccard_similarity        385 non-null    float64
#  7   overlap_count             385 non-null    int64
#  8   min_token_len_matched     385 non-null    int64
#  9   max_token_len_matched     385 non-null    int64
#  10  mean_token_len_matched    385 non-null    float64
#  11  num_uk_tokens             385 non-null    int64
#  12  num_eu_tokens             385 non-null    int64
#  13  label                     385 non-null    object
# dtypes: float64(3), int64(8), object(3)
# memory usage: 42.2+ KB

# %%
df_full.head()
# Out:
#    uk_id                                                                                                            uk_name  eu_id                                                                                                            eu_name  final_multi_score  avg_adjusted_token_score  jaccard_similarity  overlap_count  min_token_len_matched  max_token_len_matched  mean_token_len_matched  num_uk_tokens  num_eu_tokens
# 0   6894  {'Rahman', 'Fikiruddin', 'Fihiruddin', 'Muqti', 'A', 'Jibril', 'Abu', 'Abdurrahman', 'Iqbal', 'Abdul', 'Mohamad'}   1004  {'Fikiruddin', 'Rahman', 'Fihiruddin', 'A', 'Muqti', 'Jibril', 'Abu', 'Abdurrahman', 'Iqbal', 'Abdul', 'Mohamad'}                 97                     96.00                 1.0              9                      1                     11                    6.00             11             11
# 1   6895                                                                                 {'Hazem', 'Qader', 'Abdul', 'Hai'}    505                                                                                 {'Abdul', 'Hai', 'Hazem', 'Qader'}                 95                     93.00                 1.0              4                      3                      5                    4.50              4              4
# 2   6897                                                     {'Am', 'Agha', 'Man', 'Abd', 'Manan', 'Saiyid', 'Abdul', 'Al'}    514                                 {'Abdul', 'Am', 'Bd', 'Agha', 'Ag', 'Man', 'Abd', 'Saiyid', 'Manan', 'Lmnn', 'Al'}                 93                     90.50                 1.0              6                      2                      6                    3.33              8             11
# 3   6899                                 {'Abdallah', 'Shahata', 'Tharwat', 'Tarwat', 'Shihata', 'Ali', 'Salah', 'Thirwat'}    796                                 {'Abdallah', 'Shahata', 'Tharwat', 'Tarwat', 'Shihata', 'Ali', 'Salah', 'Thirwat'}                 97                     96.40                 1.0              5                      3                      8                    6.00              8              8
# 4   6901                                                                           {'Abdul', 'Majeed', 'Majid', 'Chaudhry'}    641                                                                           {'Abdul', 'Majeed', 'Majid', 'Chaudhry'}                 99                     98.33                 1.0              3                      5                      8                    6.33              4              4

# %%
df_label.head()
# Out:
#    uk_id                                                                                                                                uk_name  eu_id                                                                                                                                eu_name  final_multi_score  avg_adjusted_token_score  jaccard_similarity  overlap_count  min_token_len_matched  max_token_len_matched  mean_token_len_matched  num_uk_tokens  num_eu_tokens  label
# 0   6894                      {'Rahman', 'Fikiruddin', 'Fihiruddin', 'Muqti', 'A', 'Jibril', 'Abu', 'Abdurrahman', 'Iqbal', 'Abdul', 'Mohamad'}   1004                      {'Fikiruddin', 'Rahman', 'Fihiruddin', 'A', 'Muqti', 'Jibril', 'Abu', 'Abdurrahman', 'Iqbal', 'Abdul', 'Mohamad'}                 97                     96.00                 1.0              9                      1                     11                    6.00             11             11  match
# 1   6905                                                                        {'Zakir', 'Bari', 'Haji', 'Sahib', 'Abdul', 'Mullah', 'Akhund'}    556                                                                        {'Zakir', 'Bari', 'Haji', 'Sahib', 'Abdul', 'Mullah', 'Akhund'}                 97                     96.43                 1.0              7                      4                      6                    5.00              7              7  match
# 2   6912                                                                                                   {'Abdul', 'Khadem', 'Rauf', 'Aliza'}    719                                                                                         {'Khadem', 'Aliza', 'Abdul', 'Mullah', 'Rauf'}                 97                     96.25                 1.0              4                      4                      6                    5.00              4              5  match
# 3   6932  {'Samman', 'Ismail', 'Filistini', 'Othman', 'Takfiri', 'Mahmoud', 'Uthman', 'Omar', 'Qatada', 'Umar', 'Abu', 'Mohammed', 'Al', 'Umr'}    836  {'Samman', 'Ismail', 'Filistini', 'Othman', 'Takfiri', 'Mahmoud', 'Uthman', 'Omar', 'Qatada', 'Umar', 'Abu', 'Mohammed', 'Al', 'Umr'}                 97                     96.33                 1.0             12                      2                      9                    5.58             14             14  match
# 4   7024                                            {'Abdallah', 'Hannachi', 'Ben', 'Belgacem', 'Mohamed', 'Fathi', 'Aouadi', 'Belkacem', 'Al'}    927                                            {'Abdallah', 'Ben', 'Belgacem', 'Fathi', 'Mohamed', 'Hannachi', 'Aouadi', 'Belkacem', 'Al'}                 97                     96.12                 1.0              8                      2                      8                    5.88              9              9  match

# %% [markdown]
# ### Defining variables

# %%
#define relevant columns as features
feature_cols=[
    'final_multi_score',
    'avg_adjusted_token_score',
    'jaccard_similarity',
    'overlap_count',
    'min_token_len_matched',
    'max_token_len_matched',
    'mean_token_len_matched',
    'num_uk_tokens',
    'num_eu_tokens'
]

#get the uk ids of labelled data
labelled_ids=df_label['uk_id']

#create a dataframe without the labelled rows
df_holdout=df_full[~df_full['uk_id'].isin(labelled_ids)]


#extract features and target labels for training and holdout sets
X=df_label[feature_cols]  
y=df_label['label'] 
X_holdout=df_holdout[feature_cols]

# %% [markdown]
# # Methodology & Rationale

# %% [markdown]
# ### Classifier

# %% [markdown]
# - **Random Forest** was initially selected as a starting point. It's a robust and versatile classifier that performs well with minimal tuning and can handle complex patterns in the data. As a first model, it provided a solid baseline for comparison, delivering good results with relatively low effort
#
# - **Logistic Regression** was explored next to test whether a simpler, more interpretable model could offer similar performance. Both L1 and L2 regularization were tested against each other. Since the L1 model showed better results, it was optimized in a dedicated follow-up experiment.
#
#
# - **XGBoost**  was selected as the next step. This more advanced boosting algorithm is known for handling complex relationships in data while offering higher flexibility. Given its track record of high performance on structured data and its ability to manage overfitting, it was a natural progression to test whether it could outperform the previous models, especially after tuning hyperparameters

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# - **GridSearchCV** was used to find the combination of hyperparameters that gave the best performance estimate. A custom scoring function guided the search by reflecting the task’s specific priorities, using a weighted combination of the metrics used for evaluation.

# %% [markdown]
# ### Validation Strategy

# %% [markdown]
# - **Train-Test Split** was initially used for quick evaluation. Although class balance was maintained using stratification, the results may have underestimated model performance due to the limited sample size (385) and the variability introduced by a single random split. This limitation motivated a shift to Stratified K-Fold Cross-Validation, which provides more stable and reliable performance estimates.
#
#
#
# - **Stratified K-Fold Cross-Validation** was adopted to address those isses and still maintain class blanace. By generating multiple train-test splits and allowing every data point to be used for both training and validation, it produced more stable and robust estimates.
#
#     - 5 folds were chosen to simultaneously provide sufficient variability across splits, while preventing overfitting.

# %% [markdown]
# ### Evaluation Metrics

# %% [markdown]
# In this task, the goal is to classify names as not match, preliminary match, or match, with the emphasis on avoiding missed true matches while minimizing unnecessary manual review.
#
# We focus on the following priorities:
#
#  - **Precision** in “Match” and “Not Match” is our top priority. If the system labels something as a match, it should truly be a match. Likewise, if it says not match, it should be genuinely safe to ignore. These two classes represent confident decisions, so we want them to be as reliable as possible.
#
#  - “Preliminary Match” acts as a safety net where uncertain cases go for human review. We do not directly optimize for this class, but we rely on it to catch true matches missed
#
#  - **Recall** in “Not Match” is important but secondary. It tells us how many of the actual “not match” cases are caught confidently by the model. Higher recall here means fewer names fall into the “preliminary match” category, which helps reduce manual workload. However, this is less critical than being certain about the predictions in the match and not match classes.
#
#
#
# In summary, we want the model to be confident only when it is correct. Precision ensures that confidence is deserved, while recall helps reduce human burden. This approach ensures that true matches are not missed and that attention is focused where it is truly needed.

# %% [markdown]
# # Experimental Setup & Results

# %% [markdown]
# ### Experiment 1:
# - **Classifier**: Random Forest
# - **Hyperparameters**: Default
# - **Validation Strategy**: Simple Train-test Split
#     - split ratio: 80/20
#     - startified: yes (to maintain class balance)

# %%
#split the data into training and testing sets ensuring class balance using stratification
X_train_0, X_test_0, y_train_0, y_test_0=train_test_split(X, y, test_size=0.2, random_state=30, stratify=y)


#initialize and train model  
model_1=RandomForestClassifier(n_estimators=100, random_state=30)  #random_state=30 for reproducibility  
model_1.fit(X_train_0, y_train_0)

#get predictions on test set 
y_pred_1=model_1.predict(X_test_0)

# %%
#define class labels
class_labels=['not match','preliminary match', 'match']

#create confusion matrix
conf_matrix_1=confusion_matrix(y_test_0, y_pred_1)

#create classification report 
report_1=classification_report(y_test_0, y_pred_1, target_names=class_labels)

#extract summary metrics from report 
report_dict=classification_report(y_test_0, y_pred_1, target_names=class_labels,output_dict=True)
precision_match_1=round(report_dict['match']['precision'], 3)
precision_not_match_1=round(report_dict['not match']['precision'], 3)
recall_not_match_1=round(report_dict['not match']['recall'], 3)

#print results
print("Confusion Matrix:")
print(conf_matrix_1)
print("\nClassification Report:")
print(report_1)

print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_1}")
print(f"'Not Match' Precision: {precision_not_match_1}")
print(f"'Not Match' Recall:    {recall_not_match_1}")
# Out:
# Confusion Matrix:
# [[50  0  2]
#  [ 0  9  1]
#  [ 3  1 11]]
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#         not match       0.94      0.96      0.95        52
# preliminary match       0.90      0.90      0.90        10
#             match       0.79      0.73      0.76        15
#
#          accuracy                           0.91        77
#         macro avg       0.88      0.86      0.87        77
#      weighted avg       0.91      0.91      0.91        77
#
#
# Classification Report Summary:
# 'Match' Precision:     0.786
# 'Not Match' Precision: 0.943
# 'Not Match' Recall:    0.962

# %% [markdown]
# ### Experiment 2:
# - **Classifier**: Random Forest
# - **Hyperparameters**: Default
# - **Validation Strategy**: Stratified k-Fold CV
#    - no folds: 5 (standard choice)
#    - startified: yes (to maintain class balance)

# %%
#initialize cross validator
skf=StratifiedKFold(n_splits=5, shuffle=True, random_state=30)

#initialize model 
model_2=RandomForestClassifier(n_estimators=100, random_state=30)



conf_matrices=[]
reports=[]

#for each k fold
for train_idx, test_idx in skf.split(X, y):
    
    #split data into train and test sets
    X_train, X_test=X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test=y.iloc[train_idx], y.iloc[test_idx]

    #train model on training set
    model_2.fit(X_train, y_train)  

    #predict target values for test set
    y_pred=model_2.predict(X_test)

    #store confusion matrix and classification report for this fold
    conf_matrices.append(confusion_matrix(y_test, y_pred))
    reports.append(classification_report(y_test, y_pred, target_names=class_labels, output_dict=True))



#aggregate confusion matrices acorss all folds
conf_matrix_2=np.sum(conf_matrices, axis=0)

#extract class-specific metrics from each fold
precision_match=[r['match']['precision'] for r in reports]
precision_not_match=[r['not match']['precision'] for r in reports]
recall_not_match=[r['not match']['recall'] for r in reports]

#average metrics across all folds
precision_match_2= round(np.mean(precision_match), 3)
precision_not_match_2= round(np.mean(precision_not_match), 3)
recall_not_match_2= round(np.mean(recall_not_match), 3)




#print results
print("Confusion Matrix:")
print(conf_matrix_2)

print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_2}")
print(f"'Not Match' Precision: {precision_not_match_2}")
print(f"'Not Match' Recall:    {recall_not_match_2}")
# Out:
# Confusion Matrix:
# [[253   0   8]
#  [  0  47   4]
#  [  5   1  67]]
#
# Classification Report Summary:
# 'Match' Precision:     0.848
# 'Not Match' Precision: 0.981
# 'Not Match' Recall:    0.969

# %% [markdown]
# ### Experiment 3:
# - **Classifier**: Random Forest
# - **Hyperparameters**: tuned with GridSearchCV + custom scoring function
#    - number of trees: 50, 100, 200
#    - tree depth: None, 10, 20
#    - min samples to split: 2, 5
#    - min samples per leaf: 1, 2
# - **Validation Strategy**: Stratified k-Fold CV
#     - number of folds: 5

# %%
#define a custom scoring function 
def priority_metric(y_true, y_pred):

    #extract the relevant metrics
    report=classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)    
    precision_match=report['match']['precision']
    precision_not_match=report['not match']['precision']
    recall_not_match=report['not match']['recall']
    
    #create weighted score based on the relative importance of each metric
    weighted_score=0.4*precision_match + 0.4*precision_not_match + 0.4*recall_not_match
    
    return weighted_score

#wrap the custom scoring function using sklearn's make_scorer for use in GridSearchCV
custom_scorer=make_scorer(priority_metric, greater_is_better=True)

# %%
#initialize base model
base_model_3=RandomForestClassifier(random_state=30)

#define standard hyperparameter grid
param_grid_3 = {
    'n_estimators':[50, 100, 200],
    'max_depth':[None, 10, 20],
    'min_samples_split':[2, 5],
    'min_samples_leaf':[1, 2]
}

#perform grid search with custom scoring function and cross-validation startegy
grid_search_3=GridSearchCV(base_model_3, param_grid_3, scoring=custom_scorer, cv=skf, n_jobs=-1)

#fit the grid search to the entire labelled dataset
grid_search_3.fit(X, y)

#store the best performing model and parameters
model_3=grid_search_3.best_estimator_
best_parameters_3=grid_search_3.best_params_

# %%
#initialize lists to store results
conf_matrices = []
reports = []

#for each k-fold
for train_idx, test_idx in skf.split(X, y):

    #split data into train and test sets
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    #train model on training set
    model_3.fit(X_train, y_train)

    #predict target values based on test data
    y_pred_3=model_3.predict(X_test)

    #store confusion matrix and classification report for this fold
    conf_matrices.append(confusion_matrix(y_test, y_pred_3)) 
    reports.append(classification_report(y_test, y_pred_3, target_names=class_labels, output_dict=True))




#aggregate confusion matrix across all folds
conf_matrix_3=np.sum(conf_matrices, axis=0)

#extract class-specific metrics from each fold
precision_match=[r['match']['precision'] for r in reports]
precision_not_match=[r['not match']['precision'] for r in reports]
recall_not_match=[r['not match']['recall'] for r in reports]

#average metrics across all folds
precision_match_3=round(np.mean(precision_match), 3)
precision_not_match_3=round(np.mean(precision_not_match), 3)
recall_not_match_3=round(np.mean(recall_not_match), 3)



#print results
print("Best hyperparameters:")
print(best_parameters_3)

print("\nConfusion Matrix:")
print(conf_matrix_3)

print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_3}")
print(f"'Not Match' Precision: {precision_not_match_3}")
print(f"'Not Match' Recall:    {recall_not_match_3}")
# Out:
# Best hyperparameters:
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
#
# Confusion Matrix:
# [[254   0   7]
#  [  0  47   4]
#  [  6   0  67]]
#
# Classification Report Summary:
# 'Match' Precision:     0.859
# 'Not Match' Precision: 0.977
# 'Not Match' Recall:    0.973

# %% [markdown]
# ### Experiment 4
# - **Classifier**: Logistic Regression
# - **Hyperparameters**: tuned with GridSearchCV + custom scoring function
#     - regularization strength C: 0.001, 0.01, 0.1, 1, 10, 100
#     - penalty: L1, L2
#     - solver: saga (works for both L1 and L2)
# - **Validation Strategy**: Stratified K-Fold
#     - number of folds: 5

# %%
#standardize features 
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

#initialize base model
base_model_4=LogisticRegression(random_state=30, max_iter=10000,solver='saga')

#define hyperparameter grid for tuning 
param_grid_4={
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  #wide range of values
    'penalty': ['l1','l2']
}

#grid search with custom scoring and stratified CV
grid_search_4 = GridSearchCV(base_model_4, param_grid_4, scoring=custom_scorer, cv=skf, n_jobs=-1)
grid_search_4.fit(X_scaled, y)

#store best performing model and parameters
model_4=grid_search_4.best_estimator_
best_parameters_4=grid_search_4.best_params_
# Out:
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
conf_matrices=[]
reports=[]

#for each k-fold
for train_idx, test_idx in skf.split(X, y):

    #split data into train and test sets
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    #standardize data 
    X_train_scaled=scaler.fit_transform(X_train)
    X_test_scaled=scaler.transform(X_test)
    
    #train model
    model_4.fit(X_train_scaled, y_train)

    #predict target values based on test data
    y_pred_4=model_4.predict(X_test_scaled)

    #store confusion matrix and classification report for this fold
    conf_matrices.append(confusion_matrix(y_test, y_pred_4)) 
    reports.append(classification_report(y_test, y_pred_4, target_names=class_labels, output_dict=True))




#aggregate confusion matrix across all folds
conf_matrix_4=np.sum(conf_matrices, axis=0)

#extract class-specific metrics from each fold
precision_match=[r['match']['precision'] for r in reports]
precision_not_match=[r['not match']['precision'] for r in reports]
recall_not_match=[r['not match']['recall'] for r in reports]

#average metrics across all folds
precision_match_4=round(np.mean(precision_match), 3)
precision_not_match_4=round(np.mean(precision_not_match), 3)
recall_not_match_4=round(np.mean(recall_not_match), 3)



#print results
print("Best hyperparameters:")
print(best_parameters_4)

print("\nConfusion Matrix:")
print(conf_matrix_4)

print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_4}")
print(f"'Not Match' Precision: {precision_not_match_4}")
print(f"'Not Match' Recall:    {recall_not_match_4}")
# Out:
# Best hyperparameters:
# {'C': 100, 'penalty': 'l1'}
#
# Confusion Matrix:
# [[252   1   8]
#  [  1  48   2]
#  [  8   3  62]]
#
# Classification Report Summary:
# 'Match' Precision:     0.874
# 'Not Match' Precision: 0.966
# 'Not Match' Recall:    0.965

# %% [markdown]
# ### Experiment 5
# - **Classifier**: Logistic Regression
# - **Hyperparameters**: tuned with GridSearchCV + custom scoring function
#     - regularization strength C: 0.001, 0.01, 0.1, 1, 10, 100
#     - penalty: L1
#     - solver: liblinear (efficient for L1)
# - **Validation Strategy**: Stratified K-Fold
#     - number of folds: 5

# %%
#initilize base model
base_model_5=LogisticRegression(random_state=30, max_iter=10000)

#define hyperparameter grid
param_grid_5={
    'C': [0.001,0.01, 0.1, 1, 10, 100],
    'penalty': ['l1'],
    'solver': ['liblinear'] 
}

#grid search with custom scoring and stratified CV 
grid_search_5=GridSearchCV(base_model_5,param_grid_5,scoring=custom_scorer,cv=skf,n_jobs=-1)
grid_search_5.fit(X_scaled, y)

#store best performing model and parameters
model_5=grid_search_5.best_estimator_
best_parameters_5=grid_search_5.best_params_
# Out:
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/India/miniconda3/envs/eu_sanctions/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
conf_matrices=[]
reports=[]

#for each k-fold
for train_idx, test_idx in skf.split(X, y):

    #split data into train and test sets
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    X_train_scaled=scaler.fit_transform(X_train)
    X_test_scaled=scaler.transform(X_test)
    
    #train model
    model_5.fit(X_train_scaled, y_train)

    #predict target values 
    y_pred_5=model_5.predict(X_test_scaled)

    #store confusion matrix and classification report for this fold
    conf_matrices.append(confusion_matrix(y_test, y_pred_5)) 
    reports.append(classification_report(y_test, y_pred_5, target_names=class_labels, output_dict=True))




#aggregate confusion matrix across all folds
conf_matrix_5=np.sum(conf_matrices, axis=0)

#extract class-specific metrics from each fold
precision_match=[r['match']['precision'] for r in reports]
precision_not_match=[r['not match']['precision'] for r in reports]
recall_not_match=[r['not match']['recall'] for r in reports]

#average metrics across all folds
precision_match_5=round(np.mean(precision_match), 3)
precision_not_match_5=round(np.mean(precision_not_match), 3)
recall_not_match_5=round(np.mean(recall_not_match), 3)




#print results
print("Best hyperparameters:")
print(best_parameters_5)

print("\nConfusion Matrix:")
print(conf_matrix_5)

print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_5}")
print(f"'Not Match' Precision: {precision_not_match_5}")
print(f"'Not Match' Recall:    {recall_not_match_5}")
# Out:
# Best hyperparameters:
# {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#
# Confusion Matrix:
# [[257   1   3]
#  [  1  47   3]
#  [ 16   4  53]]
#
# Classification Report Summary:
# 'Match' Precision:     0.898
# 'Not Match' Precision: 0.938
# 'Not Match' Recall:    0.985

# %% [markdown]
# ### Experiment 6
# - **Classifier**: XGBoost Classifier
# - **Hyperparameters**: tuned with GridSearchCV + custom scoring function
#     - no of estimators: 50, 100, 200
#     - max depth of each tree: 3, 6, 10
#     - step size shrinkage: 0.01, 0.1, 0.2
#     - row sampling: 0.7, 1.0
#     - feature sampling: 0.7, 1.0
#     - L1 regularization term: 0, 0.1, 1
#     - L2 regularization term: 1, 10
# - **Validation Strategy**: Stratified K-Fold
#     - number of folds: 5

# %%
#initialize base model
base_model_6=XGBClassifier(random_state=30, eval_metric='mlogloss')

#define hyperparameter grid for tuning
param_grid_6 = {
    'n_estimators':[50, 100, 200],           #number of trees
    'max_depth':[3, 6, 10],                  #depth of each tree
    'learning_rate':[0.01, 0.1, 0.2],        #step size shrinkage
    'subsample':[0.7, 1.0],                  # row sampling
    'colsample_bytree':[0.7, 1.0],           # feature sampling
    'reg_alpha':[0, 0.1, 1],                 # L1 regularization
    'reg_lambda':[1, 10]                     # L2 regularization
}

#encode labels as integers for compatibility with XGBClassifier
label_mapping={
    'not match': 0,
    'preliminary match': 1,
    'match': 2
}
df_label['encoded_label'] = df_label['label'].map(label_mapping)
y=df_label['encoded_label']

#create a reverse operation to use in the future and go back to readable labels
reverse_mapping={v: k for k, v in label_mapping.items()}

#grid search with custom scoring and stratified CV 
grid_search_6=GridSearchCV(estimator=base_model_6,param_grid=param_grid_6,scoring=custom_scorer,cv=skf,n_jobs=-1)
grid_search_6.fit(X_scaled,y)

#store best performing model and parameters
model_6=grid_search_6.best_estimator_
best_parameters_6=grid_search_6.best_params_

# %%
#initialize base model
base_model_6=XGBClassifier(random_state=30, eval_metric='mlogloss')

#define hyperparameter grid for tuning
param_grid_6 = {
    'n_estimators':[50, 100, 200],           # number of trees
    'max_depth':[3, 6, 10],                  # depth of each tree
    'learning_rate':[0.01, 0.1, 0.2],        # step size shrinkage
    'subsample':[0.7, 1.0],                  # row sampling
    'colsample_bytree':[0.7, 1.0],           # feature sampling
    'reg_alpha':[0, 0.1, 1],                 # L1 regularization
    'reg_lambda':[1, 10]                     # L2 regularization
}

#grid search with custom scoring and stratified CV 
grid_search_6=GridSearchCV(estimator=base_model_6,param_grid=param_grid_6,scoring=custom_scorer,cv=skf,n_jobs=-1)
grid_search_6.fit(X_scaled,y)

#store best performing model and parameters
model_6=grid_search_6.best_estimator_
best_parameters_6=grid_search_6.best_params_

# %%
conf_matrices=[]
reports=[]

#for each fold
for train_idx, test_idx in skf.split(X, y):

    #split data into 
    X_train, X_test=X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test=y.iloc[train_idx], y.iloc[test_idx]

    #standardize features
    X_train_scaled=scaler.fit_transform(X_train)
    X_test_scaled=scaler.transform(X_test)

    #train model 
    model_6.fit(X_train_scaled, y_train)

    #predict target 
    y_pred_6=model_6.predict(X_test_scaled)

    #store confusion matrix and classification report
    conf_matrices.append(confusion_matrix(y_test, y_pred_6))
    reports.append(classification_report(y_test, y_pred_6, target_names=class_labels, output_dict=True))

#aggregate confusion matrices from all folds
conf_matrix_6=np.sum(conf_matrices, axis=0)

#extract class-specific metrics from each fold
precision_match=[r['match']['precision'] for r in reports]
precision_not_match=[r['not match']['precision'] for r in reports]
recall_not_match =[r['not match']['recall'] for r in reports]

#average metrics across folds
precision_match_6=round(np.mean(precision_match), 3)
precision_not_match_6=round(np.mean(precision_not_match), 3)
recall_not_match_6=round(np.mean(recall_not_match), 3)

#print results
print("Best hyperparameters for Experiment 6:")
print(best_parameters_6)

print("\nConfusion Matrix:")
print(conf_matrix_6)

print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_6}")
print(f"'Not Match' Precision: {precision_not_match_6}")
print(f"'Not Match' Recall:    {recall_not_match_6}")
# Out:
# Best hyperparameters for Experiment 6:
# {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.7}
#
# Confusion Matrix:
# [[ 47   4   0]
#  [  1  68   4]
#  [  0  10 251]]
#
# Classification Report Summary:
# 'Match' Precision:     0.985
# 'Not Match' Precision: 0.978
# 'Not Match' Recall:    0.92

# %% [markdown]
# # Discussion

# %%
#create dataframe with results from all experiments
results_comparison= [
    {
        'Experiment': '1 (Baseline)',
        'Match Precision': precision_match_1,
        'Not Match Precision': precision_not_match_1,
        'Not Match Recall': recall_not_match_1
    },
    {
        'Experiment': '2 (Random Forest)',
        'Match Precision': precision_match_2,
        'Not Match Precision': precision_not_match_2,
        'Not Match Recall': recall_not_match_2
    },
    {
        'Experiment': '3 (Tuned Random Forest)',
        'Match Precision': precision_match_3,
        'Not Match Precision': precision_not_match_3,
        'Not Match Recall': recall_not_match_3
    },
    {
        'Experiment': '4 (LogReg L1 vs L2)',
        'Match Precision': precision_match_4,
        'Not Match Precision': precision_not_match_4,
        'Not Match Recall': recall_not_match_4
    },
    {
        'Experiment': '5 (LogReg L1 refined)',
        'Match Precision': precision_match_5,
        'Not Match Precision': precision_not_match_5,
        'Not Match Recall': recall_not_match_5
    },
    {
        'Experiment': '6 (XGBoost)',
        'Match Precision': precision_match_6,
        'Not Match Precision': precision_not_match_6,
        'Not Match Recall': recall_not_match_6
    }
]

results_df=pd.DataFrame(results_comparison)

#create new column with the custom scoring function
results_df['Custom Score']=(0.4*results_df['Match Precision']+0.4 * results_df['Not Match Precision']+0.2*results_df['Not Match Recall'])

#display cleaned results
results_df=results_df.round(3)
print(results_df)
# Out:
#                 Experiment  Match Precision  Not Match Precision  Not Match Recall  Custom Score
# 0             1 (Baseline)            0.786                0.943             0.962         0.884
# 1        2 (Random Forest)            0.848                0.981             0.969         0.925
# 2  3 (Tuned Random Forest)            0.859                0.977             0.973         0.929
# 3      4 (LogReg L1 vs L2)            0.874                0.966             0.965         0.929
# 4    5 (LogReg L1 refined)            0.898                0.938             0.985         0.931
# 5              6 (XGBoost)            0.985                0.978             0.920         0.969

# %% [markdown]
# - As expected, the baseline experiment without stratified k fold method resulted in overly optimistic results, with perfect precision and very high recall, therefore these results were not considered.
# - The highest precision for the 'match' class was 0.985, achieved in experiment 6.
# - The highest precision for the 'not match' class was 0.98, achieved by the refined L2 Logistic Regression model.
# - The highest recall for the 'not match' category was 0.94, achievd by the tuned Random Forest Model.
# - The best model overall appears to be Model 3, with precision value svery close to the maximum and maximum recall.
# - The highest Custom score was 0.972, achieved by Model 3 and corroborating its superiority.

# %% [markdown]
# # Predicting Labels

# %%
#define model
chosen_model=model_6

# %%
#train final model with the labelled data 
chosen_model.fit(X,y)

#generate class probabilities for each class 
df_predicted_1=df_holdout.copy()
df_predicted_1[['not_match_prob','preliminary_prob','match_prob']]=chosen_model.predict_proba(X_holdout)

#predict class label 
df_predicted_1['Predicted Label 1']=chosen_model.predict(X_holdout)

#reverse mapping from experiment 6 for readability of labels
df_predicted_1['Predicted Label 1']=df_predicted_1['Predicted Label 1'].map(reverse_mapping)

# %%
#create new sample 
df_review_1=df_predicted_1.sample(200, random_state=30).sort_values('uk_id').reset_index(drop=True)

#print relevant columns from the sample to inspect the labels
df_review_1[['uk_id','uk_name','eu_name','final_multi_score','avg_adjusted_token_score','jaccard_similarity','overlap_count','Predicted Label 1','match_prob','not_match_prob','preliminary_prob']].head(200)
# Out:
#      uk_id                                                                                                                                                                                                         uk_name                                                                                                                                                                                                   eu_name  final_multi_score  avg_adjusted_token_score  jaccard_similarity  overlap_count  Predicted Label 1  match_prob  not_match_prob  preliminary_prob
# 0     7309                                                                                                                                                                         {'Abdul', 'Haq', 'Motmaen', 'Abdulhai'}                                                                                                                                                                   {'Abdul', 'Haq', 'Motmaen', 'Abdulhai'}                 96                     94.00                1.00              3              match    0.709686        0.143808          0.146506
# 1     7489                                                                                                                                                       {'Thaer', 'Alouche', 'Mohamed', 'Ali', 'Isam', 'Mansour'}                                                                                                                                                 {'Thaer', 'Alouche', 'Mohamed', 'Ali', 'Isam', 'Mansour'}                 97                     96.17                1.00              6              match    0.710580        0.143989          0.145431
# 2     7860                                                               {'Damel', 'Belkasam', 'Djamel', 'Mostafa', 'Mostefa', 'Kalad', 'Bekasam', 'Fjamel', 'Mustafa', 'Barkani', 'Ali', 'Djamal', 'Moustfa', 'Balkasam'}                                                                                 {'Ly', 'Ben', 'Belkassem', 'Abou', 'Drissi', 'Noureddine', 'Ali', 'Ldrysy', 'Bn', 'Ldyn', 'Blqsm', 'Nwr', 'Faycal', 'Al'}                 79                     85.91                0.60              2          not match    0.195555        0.569903          0.234542
# 3     7878                                                                                                                   {'Kamal', 'Kamel', 'Ben', 'Kimo', 'Maoeldi', 'Hassan', 'Hamraoui', 'Mouldi', 'Al', 'Hamroui'}                                                                     {'Kamal', 'Kamel', 'Ben', 'Lhmrwy', 'Maoeldi', 'Kimo', 'Hassan', 'Kml', 'Lmwldy', 'Hamraoui', 'Mouldi', 'Bn', 'Hsn', 'Al', 'Hamroui'}                 96                     94.86                1.00              7              match    0.709380        0.143746          0.146874
# 4     8246                                                                                                                                                                                    {'Nidal', 'Rabi', 'I', 'Al'}                                                                                                                                                                              {'Nidal', 'Rabi', 'I', 'Al'}                 93                     91.00                1.00              4              match    0.710147        0.143974          0.145879
# 5     8253                                                                                                                                                                {'Hussein', 'Raghad', 'Saddam', 'Tikriti', 'Al'}                                                                                                                                                          {'Hussein', 'Raghad', 'Saddam', 'Tikriti', 'Al'}                 98                     97.40                1.00              5              match    0.706473        0.144611          0.148916
# 6     8720  {'Yusef', 'Yusif', 'Elsayed', 'Sebai', 'I', 'Elsebai', 'Abu', 'El', 'Tusnin', 'Sababt', 'Sayyed', 'Sayyid', 'Hani', 'Hany', 'Akram', 'Siba', 'Karim', 'Sabai', 'Youssef', 'Yousef', 'Sabaay', 'Al', 'Youseff'}                                                                  {'Yusif', 'Mhmd', 'Ibn', 'Muhammad', 'Lslm', 'Ywsf', 'Khattab', 'Abd', 'Yusuf', 'Salam', 'Thmn', 'Uthman', 'Shrf', 'Bd', 'Ashraf', 'Al'}                 81                     91.00                0.50              2  preliminary match    0.217390        0.384714          0.397896
# 7     8781                                                                                                                           {'Kaua', 'Ahmad', 'Farhad', 'Omar', 'Kawa', 'Hamawandi', 'Achmed', 'Kanabi', 'Ahmed'}                                                                                                                     {'Kaua', 'Ahmad', 'Farhad', 'Omar', 'Kawa', 'Hamawandi', 'Achmed', 'Kanabi', 'Ahmed'}                 98                     97.50                1.00              6              match    0.710174        0.143843          0.145984
# 8     9065                                                                                                                                                                                     {'Straton', 'Io', 'Musoni'}                                                                                                                                                                               {'Straton', 'Io', 'Musoni'}                 97                     95.67                1.00              3              match    0.710580        0.143989          0.145431
# 9    10674                                                                                                 {'Mateso', 'Bigurura', 'Deogratias', 'Izabayo', 'Jules', 'Deo', 'Bigaruka', 'Nzeyimana', 'Mlamba', 'Stanislas'}                                                                                           {'Mateso', 'Bigurura', 'Deogratias', 'Jules', 'Izabayo', 'Deo', 'Bigaruka', 'Nzeyimana', 'Mlamba', 'Stanislas'}                 98                     98.00                1.00              9              match    0.710669        0.143943          0.145388
# 10   11233                                                                                                                                                                {'Fattah', 'Parviz', 'Seyed', 'Fatah', 'Parvis'}                                                                                                                                                                                       {'Fatah', 'Parviz'}                 85                     97.50                0.75              2  preliminary match    0.220825        0.176970          0.602205
# 11   11583                                                                                                                                                          {'Moqaddam', 'Ahmadi', 'Ismael', 'Moghadam', 'Esmail'}                                                                                                                                                                          {'Ahmadi', 'Esmail', 'Moqaddam'}                 94                    100.00                0.75              3              match    0.609685        0.164213          0.226102
# 12   11688                                                                                                                                   {'Butaev', 'Doku', 'Butayev', 'Dokka', 'Ali', 'Umarov', 'Khamatovich', 'Lom'}                                                                                                {'Butaev', 'Umarow', 'Doku', 'Butayev', 'Hamatovic', 'Chamatowicz', 'Ali', 'Umarov', 'Khamatovich', 'Lom'}                 93                     94.83                0.86              6              match    0.685544        0.148030          0.166426
# 13   11705                                                                                                                                                              {'Abdelbakir', 'Fakhiri', 'Mohamad', 'Abdelkebir'}                                                                                                                                                                      {'Fakhiri', 'Mohamad', 'Abdelkebir'}                100                    100.00                1.00              3              match    0.710221        0.143852          0.145926
# 14   11789                                                                                                                                                                                     {'Akbar', 'Ali', 'Yasaghi'}                                                                                                                                                                               {'Akbar', 'Ali', 'Yasaghi'}                 96                     94.00                1.00              3              match    0.709686        0.143808          0.146506
# 15   11805                                                                                                                                                                                        {'Mostafa', 'Bozorgnia'}                                                                                                                                                                                  {'Mostafa', 'Bozorgnia'}                 85                    100.00                1.00              2              match    0.522994        0.181564          0.295441
# 16   11808                                                                                                                                                                                 {'Mohammad', 'Ali', 'Zanjirei'}                                                                                                                                                                           {'Mohammad', 'Ali', 'Zanjirei'}                 97                     95.67                1.00              3              match    0.710605        0.143994          0.145401
# 17   11901                                                                                                                                                                                    {'Mamluk', 'Ali', 'Mamlouk'}                                                                                                                                                          {'Ly', 'Abbas', 'Mhmwd', 'Mahmoud', 'Ali', 'Bs'}                 81                     79.21                0.86              2          not match    0.206880        0.538772          0.254348
# 18   12020                                                                 {'Abdurrahim', 'Rochim', 'Asyir', 'Bashir', 'Abdurrochim', 'Abd', 'Ba', 'Abdurrahman', 'Abdurochim', 'Abdul', 'Rachim', 'Rahim', 'Aysir', 'Al'}                                                                                     {'Kani', 'Abdel', 'Bdlrhymlkn', 'Abderrahim', 'Y', 'Abd', 'Khalifa', 'Abdarrahim', 'Abdul', 'Rahim', 'Shaqaqi', 'Al'}                 87                     90.42                0.75              4  preliminary match    0.291150        0.166514          0.542336
# 19   12047                                                                                                                                   {'Hussein', 'Hussain', 'Nofal', 'Husayn', 'Nawfal', 'Nawfel', 'Nawful', 'Al'}                                                                                                            {'Hussein', 'Hussain', 'Nwfl', 'Nofal', 'Husayn', 'Nawfal', 'Lhsyn', 'Nawfel', 'Nawful', 'Al'}                 97                     96.40                1.00              5              match    0.710498        0.143973          0.145529
# 20   12052                                                                                                                                                                                           {'Mohammed', 'Jabir'}                                                                                      {'Abdallah', 'Muhammad', 'Ahmad', 'Ghani', 'Jaber', 'Jabir', 'Jalahmah', 'Jalhami', 'Abu', 'Abdul', 'Jalamah', 'Al'}                 85                     85.00                0.88              2  preliminary match    0.213272        0.311221          0.475507
# 21   12214                                                                                                                                                                                   {'Bilal', 'Ghassan', 'Belal'}                                                                                                                                                               {'Bll', 'Ghassan', 'Belal', 'Bilal', 'Gsn'}                 85                     97.50                1.00              2  preliminary match    0.278635        0.164409          0.556957
# 22   12234                                                                                                                                                                                   {'Milad', 'Jaferi', 'Jafari'}                                                                                                                                                                  {'Milad', 'Dzafari', 'Jaferi', 'Jafari'}                 85                     97.50                1.00              2  preliminary match    0.360800        0.164548          0.474652
# 23   12441                                                                                                             {'So', 'Myong', 'Chol', 'Sok', 'Tong', 'Myo', 'Kim', 'Ng', 'Hyok', 'K', 'Chin', 'Jin', 'Ong', 'My'}                                                                                                       {'So', 'Myong', 'Chol', 'Sok', 'Tong', 'Jin', 'Kim', 'Ng', 'Hyok', 'K', 'Chin', 'Myo', 'Ong', 'My'}                 93                     90.33                1.00             12              match    0.707519        0.143441          0.149041
# 24   12497                                                                                                                                {'Hojatoleslam', 'Hojjat', 'Saidi', 'Ali', 'Eslam', 'Saeedi', 'Shahroudi', 'Al'}                                                                                                                                       {'Hojatoleslam', 'Hojjat', 'Saidi', 'Ali', 'Eslam', 'Saeedi', 'Al'}                 92                     95.40                0.83              5              match    0.675692        0.151646          0.172662
# 25   12657                                                                                                                                                                                   {'Ali', 'Fahradi', 'Farhadi'}                                                                                                                                                                                        {'Ali', 'Farhadi'}                 85                     93.50                1.00              2              match    0.455723        0.177522          0.366755
# 26   12791                                                                                                                                                                                             {'Razan', 'Othman'}                                                                                                                                                                        {'Rzn', 'Razan', 'Othman', 'Thmn'}                 85                     97.50                1.00              2  preliminary match    0.260177        0.167398          0.572425
# 27   12813                                                                                                                           {'Mir', 'Wali', 'Muhammad', 'Salam', 'Khudai', 'Qasim', 'Mohammed', 'Abdul', 'Rahim'}                                                                                                                     {'Mir', 'Wali', 'Muhammad', 'Salam', 'Khudai', 'Mohammed', 'Qasim', 'Abdul', 'Rahim'}                 96                     95.25                1.00              8              match    0.710523        0.143978          0.145499
# 28   12850                                                                                                                                                                                          {'Kiasati', 'Morteza'}                                                                                                                                                                                    {'Kiasati', 'Morteza'}                 85                    100.00                1.00              2              match    0.526056        0.180129          0.293815
# 29   12859                                                                                                                   {'Hamada', 'Ould', 'Mohamed', 'Abou', 'El', 'Khairy', 'Hamad', 'Qumqum', 'Lemine', 'Kheirou'}                                                                                                             {'Hamada', 'Ould', 'Mohamed', 'Abou', 'El', 'Khairy', 'Hamad', 'Lemine', 'Qumqum', 'Kheirou'}                 98                     97.44                1.00              9              match    0.705396        0.144988          0.149615
# 30   12867                                                                                                                                                                                    {'Khan', 'Adam', 'Achekzai'}                                                                                                                                                                   {'Adam', 'Maulavi', 'Khan', 'Achekzai'}                 98                     96.67                1.00              3              match    0.710605        0.143994          0.145401
# 31   12890                                                                                   {'Darnavi', 'Masli', 'Hamza', 'Muhammad', 'Abd', 'Dirnawi', 'Abdullah', 'Hamid', 'Abu', 'Musalli', 'Darnawi', 'Al', 'Hamzah'}                                                                             {'Darnavi', 'Muhammad', 'Hamza', 'Masli', 'Abd', 'Dirnawi', 'Abdullah', 'Hamid', 'Abu', 'Musalli', 'Darnawi', 'Al', 'Hamzah'}                 96                     94.60                1.00             10              match    0.709380        0.143746          0.146874
# 32   12913                                                                                                                                                                       {'Dzhabarov', 'Michailovich', 'Vladimir'}                                                                                                                                    {'Michajlovitj', 'Vladimir', 'Dzjabarov', 'Dzhabarov', 'Michailovich'}                100                    100.00                1.00              3              match    0.710443        0.144331          0.145227
# 33   12926                                                                                                                                      {'Mikhailovich', 'Oleksiy', 'Chaliy', 'Chalyy', 'Mykhaylovych', 'Aleksei'}                                                                {'Mikhailovich', 'Oleksiy', 'Chaliy', 'Chalyy', 'Oleksij', 'Michajlovitj', 'Tjalyj', 'Aleksej', 'Mykhaylovych', 'Mychajlovytj', 'Aleksei'}                100                    100.00                1.00              3              match    0.709693        0.143745          0.146562
# 34   12930                                                                                                                                                                           {'Aleksandr', 'Viktorovich', 'Vitko'}                                                                                                                                                      {'Aleksandr', 'Viktorovich', 'Viktorovitj', 'Vitko'}                 99                     98.33                1.00              3              match    0.710751        0.143960          0.145290
# 35   12933                                                                                                                                  {'Grigoryevich', 'Mikhail', 'Mykhalyo', 'Mykhaylo', 'Malyshev', 'Hryhorovych'}                               {'Mikhailo', 'Grigorievich', 'Hryhorovytj', 'Mikhail', 'Grigorjevitj', 'Malishev', 'Mykhaylo', 'Malyshev', 'Grigorovich', 'Mychajlo', 'Malysjev', 'Michail', 'Hryhorovych'}                 99                     99.25                0.98              5              match    0.709730        0.143753          0.146517
# 36   12939                                                                                                                                                                         {'Mihailovich', 'Nosatov', 'Alexander'}                                                                                                                      {'Aleksandr', 'Mikhailovich', 'Michajlovitj', 'Alexander', 'Mihailovich', 'Nosatov'}                100                    100.00                1.00              3              match    0.710751        0.143960          0.145290
# 37   12952                                                                                                                                                                            {'Genrikhovich', 'Oleg', 'Savelyev'}                                                                                                                                                                      {'Genrikhovich', 'Oleg', 'Savelyev'}                 99                     98.33                1.00              3              match    0.710221        0.143852          0.145926
# 38   13075                                                                                                                                                         {'Valentinovich', 'Yuriy', 'Kovalchuk', 'Yuri', 'Yury'}                                                                                                {'Valentinovich', 'Valentinovic', 'Valentinovitj', 'Kovaltjuk', 'Jurij', 'Yuriy', 'Kovalchuk', 'Kovalcuk'}                 99                     98.33                1.00              3              match    0.710633        0.143936          0.145432
# 39   13095                                                                                                                                                       {'Pinchuk', 'Yuriyovych', 'Andrey', 'Yurevich', 'Andriy'}                                                                                        {'Yuriyovych', 'Pinchuk', 'Andrey', 'Pintjuk', 'Andrej', 'Yurevich', 'Andrij', 'Jurijovytj', 'Andriy', 'Jurevitj'}                100                    100.00                1.00              4              match    0.710669        0.143943          0.145388
# 40   13100                                                                                                                                    {'Serhiyovych', 'Mikhail', 'Sergeyevich', 'Sheremet', 'Heremet', 'Mykhaylo'}                                                             {'Serhiyovych', 'Sheremet', 'Sergeyevich', 'Mikhail', 'Seremet', 'Sjeremet', 'Mykhaylo', 'Mychajlo', 'Serhijovytj', 'Sergejevitj', 'Michail'}                100                    100.00                1.00              5              match    0.709730        0.143753          0.146517
# 41   13127                             {'Azam', 'Maky', 'Abdullah', 'Abu', 'Mansur', 'Azzam', 'Harbi', 'Subhi', 'Abdallah', 'Maulid', 'Razeeq', 'Ar', 'Zureik', 'Muslem', 'Alsbhua', 'Mouled', 'Suliman', 'Abdalla', 'Al'}                       {'Azam', 'Maky', 'Abdullah', 'Abu', 'Mansur', 'Azzam', 'Harbi', 'Subhi', 'Abdallah', 'Maulid', 'Razeeq', 'Ar', 'Zureik', 'Muslem', 'Alsbhua', 'Mouled', 'Suliman', 'Abdalla', 'Al'}                 97                     96.31                1.00             16              match    0.710276        0.143928          0.145797
# 42   13145                                                                                                                                                                            {'Jan', 'Abid', 'Khan', 'Saidullah'}                                                                                                                                                                      {'Jan', 'Abid', 'Saidullah', 'Khan'}                 96                     94.25                1.00              4              match    0.709824        0.143772          0.146404
# 43   13191                                                                                                                                       {'Badr', 'Yunus', 'Houthi', 'Din', 'Abd', 'Abu', 'Huthi', 'Khaliq', 'Al'}                                                                                                                                 {'Badr', 'Yunus', 'Din', 'Houthi', 'Abd', 'Abu', 'Huthi', 'Khaliq', 'Al'}                 94                     92.25                1.00              8              match    0.709796        0.144091          0.146113
# 44   13285                                                                                                                                                                             {'Umm', 'Layth', 'Mahmood', 'Aqsa'}                                                                                                                                                                       {'Umm', 'Layth', 'Mahmood', 'Aqsa'}                 96                     94.25                1.00              4              match    0.710561        0.143986          0.145454
# 45   13335                                                                                                                                                                      {'Myong', 'Tae', 'Kim', 'Gi', 'Ko', 'Hun'}                                                                                                                                                                {'Myong', 'Tae', 'Kim', 'Gi', 'Ko', 'Hun'}                 91                     88.33                1.00              6              match    0.690515        0.165720          0.143764
# 46   13344                                                                                                                                                  {'Messie', 'Le', 'Sanglant', 'Rao', 'Kony', 'Joseph', 'Josef'}                                                                                                                                            {'Messie', 'Le', 'Sanglant', 'Rao', 'Kony', 'Joseph', 'Josef'}                 96                     94.83                1.00              6              match    0.709711        0.143813          0.146476
# 47   13378                                                                              {'Labola', 'Lalobo', 'Labolo', 'Kony', 'Kapere', 'Mohammad', 'Ali', 'Salongo', 'Otim', 'One', 'Mohammed', 'Caesar', 'P', 'Bashir'}                                                           {'Shaukan', 'Meddie', 'Punisher', 'Boy', 'Mohamed', 'Abou', 'Abu', 'Defender', 'Ali', 'Kasibante', 'Punny', 'Nkalubo', 'Abdul', 'Lee', 'Jihad'}                 80                     90.17                0.50              2  preliminary match    0.213871        0.389564          0.396565
# 48   13401                                                                                                                                         {'Ahmad', 'Muhammad', 'Mohamed', 'Mohammad', 'Mohammed', 'Al', 'Ahmed'}                                                                               {'Ahdal', 'Muhammad', 'Mohamed', 'Asim', 'Makki', 'Hamati', 'Abdullah', 'Hamdi', 'Mohammad', 'Abu', 'Sadiq', 'Ahmed', 'Al'}                 97                     95.50                1.00              4              match    0.710276        0.143928          0.145797
# 49   13448                                                                                                                                               {'Abdallah', 'Ghalib', 'Zaidi', 'Zaydi', 'Abdullah', 'Ali', 'Al'}                                                                                                                                         {'Abdallah', 'Ghalib', 'Zaidi', 'Zaydi', 'Abdullah', 'Ali', 'Al'}                 97                     95.50                1.00              4              match    0.710605        0.143994          0.145401
# 50   13480                                                                                                                                                                         {'Do', 'Chun', 'Un', 'To', 'Ch', 'Pak'}                                                                                                                                                                   {'Do', 'Chun', 'Un', 'To', 'Ch', 'Pak'}                 91                     88.33                1.00              6              match    0.688266        0.166961          0.144772
# 51   13482                                                                                                                                                                                            {'Yong', 'Su', 'Ri'}                                                                                                                                                                                      {'Ri', 'Su', 'Yong'}                 92                     89.67                1.00              3              match    0.706475        0.144773          0.148751
# 52   13488                                                                                                                                                                         {'Yong', 'Cho', 'Jo', 'Won', 'Yongwon'}                                                                                                                                                                   {'Yong', 'Cho', 'Jo', 'Won', 'Yongwon'}                 92                     89.00                1.00              4              match    0.707492        0.144917          0.147591
# 53   13502                                                                                                                                                                                {'Ghriwati', 'Ziad', 'Mohammad'}                                                                                                                                    {'Mhmd', 'Grywty', 'Mohammad', 'Ziad', 'Zyd', 'Ghriwati', 'Ghraywati'}                 99                     98.33                1.00              3              match    0.709538        0.144246          0.146217
# 54   13529                                                                                                                                                                                        {'Chol', 'Song', 'Jang'}                                                                                                                                                                                  {'Chol', 'Song', 'Jang'}                 96                     95.00                1.00              3              match    0.707820        0.144804          0.147376
# 55   13566                                                                                                                                                                           {'Hwan', 'Ng', 'Kyo', 'Mun', 'Kyong'}                                                                                                                                                                     {'Hwan', 'Ng', 'Kyo', 'Mun', 'Kyong'}                 92                     89.00                1.00              4              match    0.707492        0.144917          0.147591
# 56   13567                                                                                                                                                                                 {'Uk', 'Pae', 'Wo', 'Won', 'N'}                                                                                                                                                                           {'Uk', 'Pae', 'Wo', 'Won', 'N'}                 90                     87.00                1.00              4              match    0.618911        0.179577          0.201512
# 57   13690                                                                                                                                                                                  {'Sandra', 'Ruzza', 'Oblitas'}                                                                                                                                                                            {'Sandra', 'Ruzza', 'Oblitas'}                 99                     98.33                1.00              3              match    0.707012        0.144721          0.148267
# 58   13706                                       {'Sahrawi', 'Abou', 'Abdi', 'Ould', 'Abu', 'El', 'Sidi', 'Lehbib', 'Adnan', 'Sahraoui', 'Said', 'Bachir', 'Ali', 'Joumani', 'Lahbib', 'Walid', 'Idrissi', 'Waleed', 'Al'}  {'Sahrawi', 'Abou', 'Bw', 'Dnn', 'Abdi', 'Ould', 'Abu', 'El', 'Sidi', 'Lehbib', 'Adnan', 'Sahraoui', 'Said', 'Bachir', 'Lshrwy', 'Ali', 'Joumani', 'Lahbib', 'Wlyd', 'Walid', 'Idrissi', 'Waleed', 'Al'}                 97                     95.69                1.00             13              match    0.710251        0.143923          0.145827
# 59   13711                                                                                                                     {'Awad', 'Saeed', 'Hamed', 'Aissa', 'Dawoud', 'Ibrahim', 'Salem', 'Jadhran', 'Salim', 'Al'}                                                                                                               {'Awad', 'Saeed', 'Hamed', 'Aissa', 'Dawoud', 'Ibrahim', 'Salem', 'Jadhran', 'Salim', 'Al'}                 97                     95.78                1.00              9              match    0.710498        0.143973          0.145529
# 60   13714                                                                                                                                                                          {'Abu', 'Choudary', 'Luqman', 'Anjem'}                                                                                                                                                                    {'Choudary', 'Luqman', 'Abu', 'Anjem'}                 97                     95.50                1.00              4              match    0.710605        0.143994          0.145401
# 61   13719                                                                                                                                                                                               {'Salah', 'Badi'}                                                                                                                                                                                         {'Salah', 'Badi'}                 85                     95.00                1.00              2              match    0.426111        0.184477          0.389412
# 62   13720                                                                                              {'Abdallah', 'Abdelnasser', 'Khuwayt', 'Taha', 'Abd', 'Ibrahim', 'Nasr', 'Bakr', 'Hajji', 'Nasir', 'Mullah', 'Al'}                                       {'Taha', 'Abd', 'L', 'Bakr', 'Hajji', 'Th', 'Ibrahim', 'Bd', 'Abdallah', 'Bkr', 'Abdelnasser', 'Nasr', 'Khuwayt', 'Nasir', 'Mullah', 'Khwyt', 'Brhym', 'Llh', 'Al'}                 97                     95.82                1.00             11              match    0.710394        0.143887          0.145718
# 63   13736                                                                                                                                                                                          {'Thu', 'Aung', 'Myo'}                                                                                                                                                                                    {'Myo', 'Aung', 'Thu'}                 92                     89.67                1.00              3              match    0.705360        0.145323          0.149317
# 64   13755                                                                                                                                                                     {'Foz', 'Samer', 'Fawz', 'Zuhair', 'Samir'}                                                                                                                                          {'Samer', 'Foz', 'Fawz', 'Fwz', 'Smr', 'Zuhair', 'Bin', 'Samir'}                 96                     94.25                1.00              4              match    0.710479        0.143969          0.145552
# 65   13759                                                                                                                                                                                  {'Bashar', 'Assi', 'Mohammad'}                                                                                                                                        {'Muhammad', 'Bashar', 'Ayyub', 'Ayub', 'Qari', 'Bashir', 'Alhaj'}                 85                     93.75                0.75              2  preliminary match    0.160271        0.149284          0.690446
# 66   13779                                                                                                                                                                               {'Andrei', 'Borisovich', 'Shein'}                                                                                                                                                               {'Andrei', 'Borisovich', 'Shein', 'Andrey'}                 99                     98.33                1.00              3              match    0.710751        0.143960          0.145290
# 67   13793                                                                                                                                                                   {'Calderon', 'Chirinos', 'Alberto', 'Carlos'}                                                                                                                                                             {'Calderon', 'Chirinos', 'Alberto', 'Carlos'}                100                    100.00                1.00              4              match    0.709682        0.144275          0.146043
# 68   13845                                                                                                                                                                            {'Jose', 'Juan', 'Jover', 'Mendoza'}                                                                                                                                                                      {'Jose', 'Juan', 'Jover', 'Mendoza'}                 97                     96.25                1.00              4              match    0.710580        0.143989          0.145431
# 69   13850                                                                                                                                                                              {'Franklyn', 'Leonardo', 'Duarte'}                                                                                                                                                                        {'Franklyn', 'Leonardo', 'Duarte'}                100                    100.00                1.00              3              match    0.708662        0.144068          0.147271
# 70   13879                                                                                                                                              {'Turki', 'M', 'Sehri', 'Alshehri', 'Muserref', 'Musherref', 'Al'}                                                                                                                                            {'Turki', 'Hishan', 'Mazidih', 'Akram', 'Abu', 'Jarrah', 'Al'}                 83                     91.00                0.60              2  preliminary match    0.159416        0.181959          0.658625
# 71   13902                                                                                                                                                                                        {'Bryan', 'D', 'Ancona'}                                                                                                                                                                                  {'Bryan', 'D', 'Ancona'}                 96                     94.00                1.00              3              match    0.709772        0.143826          0.146402
# 72   13914                                                                                                                                                                                     {'Mousa', 'Diab', 'Moussa'}                                                                                                                                                                               {'Mousa', 'Diab', 'Moussa'}                 85                     95.00                1.00              2              match    0.475499        0.168078          0.356423
# 73   13923                                                                                         {'Karayev', 'Karaev', 'Khadzimuratovich', 'Karaeu', 'Yuri', 'Yury', 'Khadzimuratavich', 'Karayeu', 'Khadzhimuratavich'}                                                                                                {'Valentinovich', 'Valentinovic', 'Valentinovitj', 'Kovaltjuk', 'Jurij', 'Yuriy', 'Kovalchuk', 'Kovalcuk'}                 50                     84.44                0.60              1          not match    0.154332        0.691108          0.154560
# 74   13942                                                                                                                                                   {'Vasiliev', 'Anatol', 'Vasilieu', 'Anatoli', 'Anatolievich'}                                                                 {'Anatoljevitj', 'Vasiliev', 'Anatolij', 'Vasiljeu', 'Anatol', 'Vasiljev', 'Eu', 'Vasil', 'Vasilieu', 'Anatoli', 'Anatolievich', 'Evich'}                100                    100.00                1.00              3              match    0.709693        0.143745          0.146562
# 75   13953                                                                                                                                       {'Anatolyevich', 'Gurzhiy', 'Andrey', 'Gurzhy', 'Andrei', 'Anatolievich'}                                                                               {'Hurzjy', 'Anatoljevitj', 'Gurzhiy', 'Andrey', 'Andrej', 'Gurzhy', 'Anatol', 'Gurzjij', 'Andrei', 'Anatolievich', 'Evich'}                100                    100.00                1.00              3              match    0.709693        0.143745          0.146562
# 76   13959                                                                                                                {'Valeri', 'Pavlovich', 'Vakulchyk', 'Pawlavich', 'Vakulchik', 'Paulavich', 'Valeryy', 'Valery'}                            {'Chyk', 'Valeri', 'Pavlovich', 'Valeryi', 'Vakulchyk', 'Vakulchik', 'Vakultjyk', 'Vakul', 'Valery', 'Pavlovitj', 'Paulavich', 'Vakultjik', 'Valerij', 'Valeryj', 'Paulavitj'}                100                    100.00                1.00              3              match    0.708301        0.143463          0.148235
# 77   13978                                                                                                                                                                                          {'Taba', 'A', 'Darem'}                                                                                                                                                                       {'Drm', 'A', 'Tb', 'Darem', 'Taba'}                 94                     92.33                1.00              3              match    0.709709        0.144191          0.146100
# 78   13986                                                                                                                                                          {'Roman', 'Raman', 'Ivanovich', 'Melnik', 'Ivanavich'}                                                                                                            {'Roman', 'Raman', 'Nik', 'Ivanovitj', 'Mel', 'Ivanovich', 'Melnik', 'Ivanavitj', 'Ivanavich'}                 99                     98.33                1.00              3              match    0.710008        0.143809          0.146183
# 79   13998                                                                                                                                                             {'Ghobash', 'Hassan', 'Ghabbash', 'Ghabache', 'Al'}                                                                                                                                        {'Ghobash', 'Ghabbash', 'Hassan', 'Gbsh', 'Ghabache', 'Hsn', 'Al'}                 98                     96.75                1.00              4              match    0.709995        0.143871          0.146134
# 80   14029                                                                                                                                                            {'Aleksandr', 'Vasilevich', 'Shakutin', 'Alexander'}                                                                {'Aleksandr', 'Shakutsin', 'Sjakutsin', 'Aljaksandr', 'Aliaksandr', 'Vasiljevitj', 'Vasilevich', 'Sjakutin', 'Vasil', 'Shakutin', 'Evich'}                100                    100.00                1.00              3              match    0.708957        0.144634          0.146409
# 81   14055                                                                                                                                                                                               {'Isaac', 'Moyo'}                                                                                                                                                {'Azzawi', 'Azzaoui', 'Hikmat', 'Ibrahim', 'Mizban', 'Al'}                 12                      0.00                0.50              0          not match    0.148365        0.700919          0.150716
# 82   14056                                                                                                                                                                                                 {'Soe', 'Htut'}                                                                                                                                                                                           {'Soe', 'Htut'}                 85                     91.00                1.00              2  preliminary match    0.402444        0.181726          0.415829
# ...
# 172  15810                                                                                                                                                                                          {'Maksim', 'Liksutov'}                                                                                                                                                             {'Maxim', 'Maksim', 'Mikhovich', 'Michovitj'}                 50                    100.00                0.60              1          not match    0.158584        0.677396          0.164021
# 173  15821                                                                                                                                                                           {'Koval', 'Georgievich', 'Alexander'}                                                                                                                                      {'Aleksandr', 'Kuznetsov', 'Alexander', 'Sergeevich', 'Sergejevitj'}                 85                     89.24                0.75              2  preliminary match    0.170768        0.179412          0.649820
# 174  15833                                                                                                                                                {'Aleksander', 'Aleksandr', 'Yurievich', 'Nazarov', 'Yuryevich'}                                                                                                                                                          {'Zverev', 'Alexander', 'Yurievich', 'Alexandr'}                 85                     93.37                0.75              2  preliminary match    0.171780        0.194390          0.633830
# 175  15834                                                                                                                                                      {'Dmitriy', 'Dmitry', 'Lelikov', 'Yurievich', 'Yuryevich'}                                                                                                                                                                        {'Dmitry', 'Lelikov', 'Yurievich'}                100                    100.00                1.00              3              match    0.710613        0.143932          0.145456
# 176  15837                                                                                                                                                               {'Vladimirovich', 'Maksim', 'Maxim', 'Vybornykh'}                                                                      {'Vladimirovich', 'Ryzjankou', 'Ryzhenkov', 'Ryzhankou', 'Maksim', 'Uladzimiravitj', 'Uladzimiravich', 'Ryzjenkov', 'Vladimirovitj'}                 85                    100.00                0.75              2  preliminary match    0.173136        0.157718          0.669146
# 177  15861                                                                                                                                                                       {'Kamal', 'Samer', 'Assad', 'Asad', 'Al'}                                                                                                                               {'Kamal', 'Sd', 'Samer', 'Assad', 'Asad', 'Smr', 'Kml', 'Samir', 'L', 'Al'}                 95                     93.00                1.00              4              match    0.709628        0.144174          0.146198
# 178  15896                                                                                                                                                                                      {'Azam', 'Sultan', 'Aziz'}                                                                                                                                                                                {'Azam', 'Sultan', 'Aziz'}                 98                     96.67                1.00              3              match    0.710580        0.143989          0.145431
# 179  15922                                                                                                                                                                          {'Leonidovich', 'Korsik', 'Alexander'}                                                                                                                                    {'Aleksandr', 'Shershnev', 'Leonidovitj', 'Leonidovich', 'Sjersjnjov'}                 85                     90.06                0.75              2  preliminary match    0.161951        0.177505          0.660544
# 180  15972                                                                                                                                                                            {'Lushnikov', 'Alan', 'Valerievich'}                                                                                                                              {'Lusnikov', 'Alan', 'Lusjnikov', 'Valerievich', 'Lushnikov', 'Valerjevitj'}                 99                     98.33                1.00              3              match    0.710751        0.143960          0.145290
# 181  16016                                                                                                                                                                         {'Ksenia', 'Mishonova', 'Vladimirovna'}                                                                                                                     {'Ksenia', 'Ksenija', 'Mishonova', 'Xenija', 'Misonova', 'Misjonova', 'Vladimirovna'}                100                    100.00                1.00              3              match    0.710751        0.143960          0.145290
# 182  16041                                                                                                                                                                              {'Mikheev', 'Danila', 'Yurievich'}                                                                                                                                  {'Michejev', 'Jurjevitj', 'Mikheev', 'Danila', 'Yurievich', 'Jurijevic'}                100                    100.00                1.00              3              match    0.709674        0.143742          0.146584
# 183  16075                                                                                                                                                                        {'Naned', 'Artem', 'Igorevich', 'Kurov'}                                                                                                                                            {'Aleksandr', 'Igorovich', 'Oleksandr', 'Igorevich', 'Kofman'}                 50                    100.00                0.50              1          not match    0.157471        0.672298          0.170232
# 184  16078                                                                                                                                                             {'Rudenskiy', 'Maksim', 'Binman', 'Buza', 'Silver'}                                                                                                                   {'Bakri', 'Muhamed', 'Abd', 'Sayyid', 'Mustafa', 'Masri', 'Ali', 'Salim', 'Al', 'Aziz'}                 50                     69.09                0.50              1          not match    0.149922        0.695711          0.154367
# 185  16182                                                                                                                                     {'Muhammad', 'Dodin', 'Mussa', 'Doudin', 'Mousa', 'Musa', 'Dudin', 'Salim'}                                                                                                                               {'Muhammad', 'Dodin', 'Mousa', 'Doudin', 'Mussa', 'Musa', 'Dudin', 'Salim'}                 97                     96.25                1.00              4              match    0.710523        0.143978          0.145499
# 186  16305                                                                                                                                                                                          {'Chit', 'Saw', 'Thu'}                                                                                                                                                           {'Saw', 'Myint', 'San', 'Maung', 'Thu', 'Chit'}                 92                     89.67                1.00              3              match    0.705360        0.145323          0.149317
# 187  16315                                                                                                                                              {'Adyani', 'Adiani', 'Hojjat', 'Islam', 'Alireza', 'Seyyed', 'Al'}                                                                                                        {'Adyani', 'Hojjat', 'Adiani', 'Dyny', 'Syd', 'Islam', 'Alireza', 'Lyrd', 'Seyyed', 'Seyed', 'Al'}                 98                     97.00                1.00              6              match    0.709639        0.143799          0.146562
# 188  16324                                                                                                                       {'Muhsen', 'Karim', 'Mohsen', 'Abd', 'Bin', 'Ali', 'Abdulkarim', 'Mohsin', 'Abdul', 'Al'}                                                  {'Ly', 'Habo', 'Karim', 'Lhbw', 'Mhmd', 'Muhammad', 'Abd', 'Mohammad', 'Habbo', 'Abdulkarim', 'Habu', 'Ali', 'Alhobo', 'Hebbo', 'Hebo', 'Mohamad', 'Al'}                 88                     92.25                0.75              4  preliminary match    0.326327        0.164836          0.508837
# 189  16379                                                                                                                                       {'Adonia', 'Le', 'Apollinaire', 'Poete', 'Hakizimana', 'Lepic', 'Amikwe'}                                                                                                                                 {'Adonia', 'Le', 'Apollinaire', 'Hakizimana', 'Poete', 'Lepic', 'Amikwe'}                 98                     96.71                1.00              7              match    0.710723        0.143954          0.145323
# 190  16384                                                                                                                                                                               {'William', 'Yakutumba', 'Amuri'}                                                                                                                                                                         {'Amuri', 'William', 'Yakutumba'}                 99                     98.33                1.00              3              match    0.710613        0.143932          0.145455
# 191  16462                                                                                                                                                                                                {'Ni', 'Gaobin'}                                                                                                                                                                 {'Ghalib', 'Nayif', 'Shindakh', 'Thamir'}                 12                      0.00                0.50              0          not match    0.148365        0.700919          0.150716
# 192  16547                                                                                                                                                            {'Lazarenko', 'Lazarenka', 'Valerievich', 'Aleksey'}                                                                                                                                            {'Aleksey', 'Vasiljevitj', 'Vasilevich', 'Naumets', 'Aleksej'}                 85                     89.24                0.75              2  preliminary match    0.163302        0.153537          0.683162
# 193  16598                                                                                                                                   {'Kirillov', 'Anatolyevich', 'Igor', 'Ihor', 'Anatoliiovych', 'Anatolievich'}                             {'Anatoljevitj', 'Krichkov', 'Kruchkov', 'Kruchkou', 'Anatolevic', 'Igar', 'Igor', 'Krutjkou', 'Krjutjkov', 'Kruckov', 'Anatol', 'Ihar', 'Anatolevich', 'Kriuchkov', 'Evich'}                 85                     97.50                0.75              2  preliminary match    0.178347        0.155832          0.665821
# 194  16680                                                                                                                                                                       {'Denis', 'Sergeev', 'Fedotov', 'Sergey'}                                                                                                                                                      {'Denis', 'Sergeevich', 'Kolesnikov', 'Sergejevitj'}                 85                     89.91                0.75              2  preliminary match    0.165156        0.162803          0.672042
# 195  16695                                                                                                                                                                                        {'Raikundalia', 'Sarju'}                                                                                                                                                           {'Rahman', 'Ahmad', 'Hottak', 'Sahib', 'Abdul'}                 12                      0.00                0.50              0          not match    0.148365        0.700919          0.150716
# 196  16712                                                                                                                                                                                 {'Aleksandre', 'Darakhvelidze'}                                                                                                   {'Dmitrij', 'Dmitrii', 'Aleksandrovitj', 'Semenov', 'Dmitry', 'Semyonov', 'Semjonov', 'Aleksandrovich'}                 50                     78.75                0.60              1          not match    0.187870        0.664636          0.147494
# 197  16733                                                                                                                                                           {'Antonio', 'Larez', 'Hernandez', 'Lares', 'Domingo'}                                                                                                                                                              {'Larez', 'Domingo', 'Antonio', 'Hernandez'}                 99                     98.75                1.00              4              match    0.710613        0.143932          0.145455
# 198  16749                                                                                                                                {'Aleksandr', 'Mishin', 'Brn', 'Igorevich', 'Triplex', 'Sasha', 'James', 'Alex'}                                                                         {'Zafir', 'Hassan', 'Sabawi', 'Abdullah', 'Bayjat', 'Awi', 'Ali', 'Ibrahim', 'Bashar', 'Sab', 'Bashir', 'Tikriti', 'Al', 'Hasan'}                 50                     72.73                0.50              1          not match    0.152900        0.692180          0.154921
# 199  16807                                                                                                                                                                          {'Porokhnya', 'Viktorovich', 'Evgeny'}                                                  {'Prigozin', 'Jevgeni', 'Viktorovitj', 'Prigojine', 'Viktorovich', 'Prigozhin', 'Jewgienij', 'Yevgeniy', 'Evgueni', 'Prigozyn', 'Prigozjin', 'Jevgenij'}                 85                     88.46                0.75              2  preliminary match    0.184230        0.199736          0.616034

# %%
#store the uk ids of rows with incorrect labels 
change_to_match=[14408,14437,15168,15350]
change_to_not_match=[8720,13378,13879,15653,15764,15821,16547]
change_to_preliminary_match=[11805,12657,12850,13401,13719,13914]

# %%
#create a new column for the human labels where the incorrect ones are properly labelled
df_review_1['Human-assigned Label']=df_review_1['Predicted Label 1'].copy()

df_review_1.loc[df_review_1['uk_id'].isin(change_to_match), 'Human-assigned Label']='match'
df_review_1.loc[df_review_1['uk_id'].isin(change_to_not_match), 'Human-assigned Label']='not match'
df_review_1.loc[df_review_1['uk_id'].isin(change_to_preliminary_match), 'Human-assigned Label']='preliminary match'

# %%
#create classification report 
report_review_1=classification_report(
    df_review_1['Human-assigned Label'],
    df_review_1['Predicted Label 1'],
    labels=class_labels,
    output_dict=True
)

#create confusion matrix
confusion_matrix_r_1=confusion_matrix(df_review_1['Human-assigned Label'], df_review_1['Predicted Label 1'],labels=class_labels)


#store relevant metrics
precision_match_r_1=report_review_1['match']['precision']
precision_not_match_r_1=report_review_1['not match']['precision']
recall_not_match_r_1=report_review_1['not match']['recall']

#print results
print(confusion_matrix_r_1)

print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_r_1}")
print(f"'Not Match' Precision: {precision_not_match_r_1}")
print(f"'Not Match' Recall:    {recall_not_match_r_1}")
# Out:
# [[ 20   7   0]
#  [  0  29   6]
#  [  0   4 134]]
#
# Classification Report Summary:
# 'Match' Precision:     0.9571428571428572
# 'Not Match' Precision: 1.0
# 'Not Match' Recall:    0.7407407407407407

# %% [markdown]
# # Retrain with new labelled data

# %%
#update training data with the most recently assigned labels
new_labelled_ids=df_review_1['uk_id']
new_labels=df_review_1['Human-assigned Label'].map(label_mapping)

new_df_label=df_full[df_full['uk_id'].isin(new_labelled_ids)].copy()
new_df_label['label']=new_labels.values

df_label=pd.concat([df_label,new_df_label],ignore_index=True)


#remove most recently assigned labelled data from holdout 
total_labelled_ids=pd.concat([labelled_ids,new_labelled_ids],ignore_index=True).sort_values().reset_index(drop=True)
df_holdout=df_full[~df_full['uk_id'].isin(total_labelled_ids)].copy()


#create final training and holdout sets
new_X=new_df_label[feature_cols]  
new_y=new_df_label['label']  
new_X_holdout=df_holdout[feature_cols]

# %%
#retrain the same model using newly labelled data 
chosen_model.fit(new_X,new_y)

#generate class probabilities for each class 
df_predicted_2=df_holdout.copy()
df_predicted_2[['not_match_prob','preliminary_prob','match_prob']]=chosen_model.predict_proba(new_X_holdout)

#predict class label 
df_predicted_2['Predicted Label 2']=chosen_model.predict(new_X_holdout)

#reverse mapping from experiment 6 for readability of labels
df_predicted_2['Predicted Label 2']=df_predicted_2['Predicted Label 2'].map(reverse_mapping)

# %%
#create a new sample from the new predictions
df_review_2=df_predicted_2.sample(200, random_state=30).sort_values('uk_id').reset_index(drop=True)

#print relevant columns for inspection of predicted labels
df_review_2[['uk_id','uk_name','eu_name','final_multi_score','avg_adjusted_token_score','jaccard_similarity','overlap_count','Predicted Label 2','match_prob','not_match_prob','preliminary_prob']].head(200)
# Out:
#      uk_id                                                                                                                                                                 uk_name                                                                                                                                                                                                          eu_name  final_multi_score  avg_adjusted_token_score  jaccard_similarity  overlap_count  Predicted Label 2  match_prob  not_match_prob  preliminary_prob
# 0     6936                                                                                                                                        {'Abu', 'Hidayatullah', 'Turab'}                                                                                                                                                                                 {'Abu', 'Hidayatullah', 'Turab'}                 96                     94.00                1.00              3              match    0.705767        0.145738          0.148495
# 1     7091                                                                                        {'Mouhajer', 'Ben', 'Elsseid', 'Omar', 'Saber', 'Saleh', 'El', 'Sami', 'Khamis'}                                                                                                                                 {'Mouhajer', 'Ben', 'Elsseid', 'Omar', 'Saber', 'Saleh', 'El', 'Sami', 'Khamis'}                 96                     94.89                1.00              9              match    0.705574        0.145979          0.148447
# 2     7123                                                                                                        {'Sarfida', 'Akhundzada', 'Ehsanullah', 'Hesamuddin', 'Sarfadi'}                                                                                                                                                 {'Sarfida', 'Akhundzada', 'Ehsanullah', 'Hesamuddin', 'Sarfadi'}                100                    100.00                1.00              4              match    0.706245        0.145836          0.147919
# 3     7164                                                                                                                                            {'Mohammad', 'Hanif', 'Din'}                                                                                                                                                                   {'Hanif', 'Iadena', 'Din', 'Mohammad', 'Qari'}                 96                     94.00                1.00              3              match    0.704480        0.145753          0.149767
# 4     7329                                                                                                              {'Karim', 'Abdullah', 'Mohammad', 'Hammad', 'Hamad', 'Al'}                                                                                                                                                       {'Karim', 'Abdullah', 'Mohammad', 'Hammad', 'Hamad', 'Al'}                 97                     95.40                1.00              5              match    0.705565        0.145978          0.148457
# 5     7449                                                                                                                                         {'Abdul', 'Ghafar', 'Shinwari'}                                                                                                                                                                                  {'Abdul', 'Ghafar', 'Shinwari'}                 99                     98.33                1.00              3              match    0.704398        0.146749          0.148853
# 6     7527                                                                                              {'Karim', 'Ud', 'Din', 'Muhammad', 'Nooruddin', 'Qasim', 'Noor', 'Turabi'}                                                                                                                               {'Karim', 'Ud', 'Din', 'Muhammad', 'Haji', 'Nooruddin', 'Qasim', 'Noor', 'Turabi'}                 96                     94.88                1.00              8              match    0.705974        0.145781          0.148245
# 7     7887                                                                                                                                                   {'Mishaal', 'Khalid'}                                                                                                                                                                                      {'Mizban', 'Khadr', 'Hadi'}                 50                     69.09                0.60              1          not match    0.154548        0.684076          0.161376
# 8     8252                                                                                                                 {'Ibrahim', 'Barzan', 'Noor', 'Tikriti', 'Al', 'Hasan'}                                                                                                                                                          {'Ibrahim', 'Barzan', 'Noor', 'Tikriti', 'Al', 'Hasan'}                 97                     96.17                1.00              6              match    0.705660        0.145997          0.148343
# 9     8352                                                                                                  {'Kamel', 'Abdeljalil', 'Adel', 'Fodhil', 'Abou', 'Djermane', 'Bilal'}                                                                                                                                 {'Kamel', 'Abdeljalil', 'Adel', 'Fodhil', 'Abou', 'Djermane', 'Bilal', 'L', 'N'}                 98                     97.14                1.00              7              match    0.704865        0.145552          0.149583
# 10    8694                                                        {'Hassan', 'Ahmad', 'Sabawi', 'Omar', 'Umar', 'Awi', 'Ali', 'Ibrahim', 'Sab', 'Alusi', 'Tikriti', 'Al', 'Hasan'}                                                                                                 {'Hassan', 'Ahmad', 'Sabawi', 'Omar', 'Umar', 'Awi', 'Ali', 'Ibrahim', 'Sab', 'Alusi', 'Tikriti', 'Al', 'Hasan'}                 96                     94.56                1.00              9              match    0.668288        0.147507          0.184205
# 11   10647                                                                                                                                                     {'Vahidi', 'Ahmad'}                                                                                                                                                                                  {'Dastjerdi', 'Vahid', 'Ahmad'}                 85                     90.68                0.95              2  preliminary match    0.160973        0.163002          0.676025
# 12   10664               {'Lakay', 'Aki', 'Rosario', 'Ahmad', 'Third', 'Santos', 'Abdullah', 'Del', 'Iii', 'Hamsa', 'Islam', 'Hilarion', 'Abu', 'Akmad', 'Aqi', 'Faisal', 'Ahmed'}                                                        {'Lakay', 'Aki', 'Rosario', 'Ahmad', 'Third', 'Santos', 'Abdullah', 'Del', 'Hamsa', 'Iii', 'Hilarion', 'Islam', 'Abu', 'Akmad', 'Aqi', 'Faisal', 'Ahmed'}                 96                     94.00                1.00             15              match    0.667847        0.148837          0.183316
# 13   10690                                                                                                                            {'Ala', 'Ammar', 'Abou', 'Djouadi', 'Yahia'}                                                                                                                                                      {'Ala', 'Ammar', 'Jwdy', 'Abou', 'Djouadi', 'Yhy', 'Yahia'}                 96                     94.40                1.00              5              match    0.705660        0.145997          0.148343
# 14   10992                                                                                                                            {'Aboubacar', 'Diakite', 'Toumba', 'Cherif'}                                                                                                                                                                     {'Aboubacar', 'Diakite', 'Toumba', 'Cherif'}                100                    100.00                1.00              4              match    0.706419        0.145872          0.147709
# 15   11039                                                                                                                                            {'So', 'Kuk', 'Sang', 'Guk'}                                                                                                                                                                              {'So', 'Kuk', 'Sang', 'Seosanggug'}                 86                     89.67                0.75              3  preliminary match    0.239774        0.208249          0.551977
# 16   11091  {'Muktar', 'Abdirahman', 'Mohamed', 'Abuzubair', 'Godani', 'Shaykh', 'Godane', 'Aw', 'Abu', 'Mohammed', 'Abdi', 'Zubeyr', 'Abdulrahim', 'Mohamud', 'Ahmed', 'Mukhtar'}                                           {'Muktar', 'Mohamud', 'Abdirahman', 'Mohamed', 'Abuzubair', 'Godani', 'Shaykh', 'Abdi', 'Aw', 'Abu', 'Mohammed', 'Godane', 'Zubeyr', 'Abdulrahim', 'Ahmed', 'Mukhtar'}                 98                     96.73                1.00             11              match    0.670784        0.148426          0.180790
# 17   11095                                                                                                                    {'Manaa', 'A', 'Fares', 'Faris', 'Mohammed', 'Mana'}                                                                                                                                                             {'Manaa', 'A', 'Fares', 'Faris', 'Mohammed', 'Mana'}                 96                     94.25                1.00              4              match    0.705745        0.146015          0.148241
# 18   11236                                                                                                                  {'Qassemi', 'Qasemi', 'Ghassemi', 'Ghasemi', 'Rostam'}                                                                                                                                                         {'Galiullovich', 'Kalimullin', 'Galiullovitj', 'Rustam'}                 50                     83.33                0.60              1          not match    0.154433        0.684720          0.160847
# 19   11639                                          {'Muammer', 'Qadhafi', 'Moatassam', 'Mutassim', 'Muatasmblla', 'Bellah', 'Abuminyar', 'Muatasimbllah', 'Almuatesem', 'Billah'}                                                                                   {'Muammer', 'Qadhafi', 'Moatassam', 'Mutassim', 'Muatasmblla', 'Bellah', 'Abuminyar', 'Muatasimbllah', 'Almuatesem', 'Billah'}                100                    100.00                1.00              7              match    0.705138        0.145608          0.149253
# 20   11648                                                                                                                                                    {'Qadhafi', 'Saadi'}                                                                                                                                                                                             {'Qadhafi', 'Saadi'}                 85                     97.50                1.00              2  preliminary match    0.158119        0.152074          0.689807
# 21   11906                                                                                                                 {'Hassan', 'Assan', 'Jameel', 'Jamieel', 'Jamil', 'Al'}                                                                                                                                                               {'Hassan', 'Jmyl', 'Jameel', 'Hsn', 'Jamil', 'Al'}                 97                     95.67                1.00              3              match    0.704358        0.145887          0.149755
# 22   12016                                                                                        {'Raif', 'Raeef', 'Quwatli', 'Kouatly', 'Quwatly', 'Ri', 'Ra', 'Af', 'If', 'Al'}                                                                                                                   {'Raeef', 'Quwatli', 'Yf', 'Ri', 'Kouatly', 'Ra', 'Quwatly', 'Lqwtly', 'Af', 'If', 'Al', 'Ry'}                 91                     91.25                0.89              8              match    0.683628        0.152477          0.163895
# 23   12042                                                         {'Shahadah', 'Shahada', 'Chahadeh', 'Rafiq', 'Rafeeq', 'Chahade', 'Shshadah', 'Shahadeh', 'Shahade', 'Chahada'}                                                                                                                                                                              {'Samira', 'Chadian', 'Shahbandar'}                 77                     78.13                0.75              2          not match    0.170752        0.619163          0.210085
# 24   12189                                                                                                                                        {'Mahsouli', 'Sadeq', 'Mahsuli'}                                                                                                                                                                                 {'Mahsouli', 'Sadeq', 'Mahsuli'}                 85                     97.50                1.00              2  preliminary match    0.180731        0.156580          0.662689
# 25   12190                                                                                                                                                   {'Mojtaba', 'Maleki'}                                                                                                                                                                                            {'Mojtaba', 'Maleki'}                 85                    100.00                1.00              2  preliminary match    0.210094        0.165175          0.624732
# 26   12191                                                                                                                                            {'Mehrdad', 'Omidi', 'Reza'}                                                                                                                                                                                     {'Mehrdad', 'Omidi', 'Reza'}                 98                     96.67                1.00              3              match    0.703596        0.145570          0.150834
# 27   12236                                                                                                                                                     {'Ali', 'Karimian'}                                                                                                                                                                                  {'Ali', 'Karimjan', 'Karimian'}                 85                     93.50                1.00              2  preliminary match    0.167068        0.154402          0.678530
# 28   12501                                                                                                                                 {'Abu', 'Chouka', 'Yassin', 'Ibraheem'}                                                                                                                                                                          {'Abu', 'Ibraheem', 'Yassin', 'Chouka'}                 98                     96.75                1.00              4              match    0.704661        0.145790          0.149549
# 29   12505                                                                                                    {'Allah', 'Azam', 'Fadl', 'Mansur', 'Azzam', 'Fadlallah', 'Mansour'}                                                                                                                        {'Mansour', 'Mnswr', 'Zm', 'Fdl', 'Allah', 'Fadl', 'Mansur', 'Azzam', 'Llh', 'Fadlallah'}                 98                     97.00                1.00              5              match    0.704388        0.145453          0.150159
# 30   12649                                                                                                                    {'Sadeq', 'Amoli', 'Larijani', 'Sadegh', 'Ardeshir'}                                                                                                                                                                                            {'Larijani', 'Sadeq'}                 85                     97.50                0.60              2  preliminary match    0.178463        0.272458          0.549079
# 31   12662                                                                                                                                          {'Reshte', 'Bahram', 'Ahmadi'}                                                                                                                                                                                   {'Reshte', 'Bahram', 'Ahmadi'}                100                    100.00                1.00              3              match    0.697660        0.147854          0.154486
# 32   12702                                                                 {'Nazar', 'Karimullah', 'Barakzai', 'Kheirullah', 'Mohammad', 'Khudai', 'Ullah', 'Khairullah', 'Khair'}                                                                                                  {'Nazar', 'Karimullah', 'Barakzai', 'Kheirullah', 'Mohammad', 'Haji', 'Khudai', 'Ullah', 'Khairullah', 'Khair'}                 99                     98.33                1.00              6              match    0.706305        0.145849          0.147846
# 33   12708                                                                                                                               {'Khallouf', 'Abou', 'Ezzat', 'Muhammad'}                                                                                                                                           {'Mhmd', 'Muhammad', 'Khallouf', 'Abou', 'Ezzat', 'Khlwf', 'Mohammed'}                 98                     97.50                1.00              4              match    0.703635        0.145578          0.150787
# 34   12729                                                                                                               {'Essam', 'Hallak', 'Hallaq', 'Halaq', 'Issam', 'Barber'}                                                                                                                                        {'Zine', 'Bent', 'Ben', 'Abidine', 'El', 'Ali', 'Haj', 'Halima', 'Hamda'}                 50                     72.73                0.50              1          not match    0.160671        0.679359          0.159969
# 35   12862                                                                                                                    {'Ag', 'Mohamed', 'Arhali', 'Sidi', 'Iyad', 'Ghali'}                                                                                                                                           {'Ag', 'Yd', 'Mohamed', 'Gly', 'G', 'Arhali', 'Sidi', 'Iyad', 'Ghali'}                 97                     95.40                1.00              5              match    0.705660        0.145997          0.148343
# 36   12865                                                                                                                           {'Khorramabadi', 'Abdolsamad', 'Khoramabadi'}                                                                                                                                                                                    {'Abdolsamad', 'Khoramabadi'}                 85                    100.00                1.00              2  preliminary match    0.332566        0.188541          0.478893
# 37   12884                                 {'Riyadh', 'Kashef', 'Ahmad', 'Muhammad', 'Kashif', 'Abd', 'Jamal', 'Al', 'Abu', 'Mohammad', 'Ahmed', 'Abdu', 'Abdo', 'Abduh', 'Rahim'}                                                                 {'Riyadh', 'Kashef', 'Gamal', 'Muhammad', 'Ahmad', 'Kashif', 'Abd', 'Jamal', 'Abu', 'Mohammad', 'Abdo', 'Abdu', 'Al', 'Abduh', 'Ahmed', 'Rahim'}                 96                     94.00                1.00              9              match    0.666780        0.148600          0.184620
# 38   12941                                                                                                                        {'Elena', 'Dmitriyeva', 'Mizulina', 'Borisovna'}                                                                                                                                         {'Mizulina', 'Dmitriyeva', 'Borisovna', 'Dmitrijeva', 'Elena', 'Jelena'}                 99                     98.75                1.00              4              match    0.706475        0.145884          0.147640
# 39   12958                                                                                                                                   {'Gerasimov', 'Vasilevich', 'Valery'}                                                                                                                                                  {'Gerasimov', 'Valerij', 'Vasiljevitj', 'Vasilevich', 'Valery'}                100                    100.00                1.00              3              match    0.705808        0.145746          0.148446
# 40   12969                                                                                                    {'Grigorievich', 'Kozyura', 'Kozura', 'Oleg', 'Oleh', 'Hryhorovych'}                                              {'Grigorjewitsch', 'Grigorievich', 'Hryhorovytj', 'Kozyura', 'Grigorjevitj', 'Oleg', 'Grigor', 'Grigorovich', 'Hryhorovych', 'Oleh', 'Koziura', 'Kosjura', 'Evich'}                 99                     98.75                1.00              4              match    0.664685        0.149536          0.185779
# 41   12994                                                                                                                                            {'Bishr', 'Yazigi', 'Riyad'}                                                                                                                                                                                     {'Bishr', 'Yazigi', 'Riyad'}                 98                     96.67                1.00              3              match    0.698539        0.148040          0.153420
# 42   13014                                                                                                      {'Vasilii', 'Oleksandrovych', 'Nikitin', 'Alexandrovich', 'Vasyl'}                                                                                                                   {'Vasilii', 'Oleksandrovich', 'Oleksandrovych', 'Nikitin', 'Vasyl', 'Vasil', 'Aleksandrovich'}                 99                     98.75                1.00              4              match    0.706475        0.145884          0.147640
# 43   13018                                                                                                             {'Nikolay', 'Ivanovich', 'Kozytsin', 'Kozitsyn', 'Nikolai'}                                                                                                                                                     {'Nikolay', 'Ivanovitj', 'Ivanovich', 'Nikolaj', 'Kozitsyn'}                100                    100.00                1.00              3              match    0.705808        0.145746          0.148446
# 44   13023                                                                                                                   {'Hashem', 'Aqqad', 'Anwar', 'Hashim', 'Akkad', 'Al'}                                                                                                                                                            {'Hashem', 'Aqqad', 'Anwar', 'Hashim', 'Akkad', 'Al'}                 96                     94.40                1.00              5              match    0.704358        0.145887          0.149755
# 45   13038                                                                                                                                   {'Gumarovich', 'Nurgaliev', 'Rashid'}                                                                                                                                      {'Gumarovitj', 'Nurgalijev', 'Gumarovich', 'Rasjid', 'Nurgaliev', 'Rashid'}                100                    100.00                1.00              3              match    0.706475        0.145884          0.147640
# 46   13182                                                                                                   {'Deynego', 'Nykolayevych', 'Vladyslav', 'Vladislav', 'Nikolayevich'}                                                            {'Vladyslav', 'Deynego', 'Nikolaevich', 'Nikolajevitj', 'Dejnego', 'Dejneho', 'Mykolajovytj', 'Mykolayovych', 'Nikolayevich', 'Vladislav', 'Deinego'}                 98                     96.88                1.00              4              match    0.704712        0.145520          0.149769
# 47   13210                                                                                                            {'Vyacheslavovich', 'Viacheslavovych', 'Yatsenko', 'Viktor'}                                                                                                   {'Vyacheslavovich', 'Vjatjeslavovitj', 'Yatsenko', 'Viacheslavovych', 'Viktor', 'Vjatjeslavovytj', 'Jatsenko'}                100                    100.00                1.00              3              match    0.705541        0.145691          0.148768
# 48   13214                                                                                                                                     {'Bakhin', 'Viktorovich', 'Arkady'}                                                                                                                                                                   {'Bakhin', 'Viktorovich', 'Arkadii', 'Arkady'}                100                    100.00                1.00              3              match    0.706419        0.145872          0.147709
# 49   13257                                                                                                                                                 {'Choe', 'Sik', 'Chun'}                                                                                                                                                                                          {'Choe', 'Sik', 'Chun'}                 94                     92.33                1.00              3              match    0.704252        0.146229          0.149518
# 50   13275                                                                                     {'Sofiane', 'Ben', 'Sufyan', 'Libi', 'Qumu', 'Abou', 'Fares', 'Bin', 'Goumo', 'Al'}                                                                                                                              {'Ben', 'Sofiane', 'Sufyan', 'Libi', 'Qumu', 'Abou', 'Fares', 'Bin', 'Goumo', 'Al'}                 95                     93.60                1.00             10              match    0.704174        0.145690          0.150136
# 51   13366                                                                                                                                                  {'Hong', 'Kim', 'Won'}                                                                                                                                                                            {'Hong', 'Gimweonhong', 'Kim', 'Won'}                 92                     89.67                1.00              3              match    0.696124        0.155900          0.147976
# 52   13387                                                                                             {'Abdul', 'Abdulqader', 'Qadir', 'Ahmad', 'Sheik', 'Sheikh', 'Al', 'Qader'}                                                                                                          {'Abdul', 'Ahmad', 'Bdlqdr', 'Sheik', 'Hmd', 'Qader', 'Lshykh', 'Abdulquader', 'Sheikh', 'Al', 'Qadir'}                 96                     94.50                0.99              6              match    0.705207        0.145622          0.149171
# 53   13391                                                                                                                              {'Bakharev', 'Mikhailovich', 'Konstantin'}                                                                                                                {'Mikhailovich', 'Baharev', 'Konstantin', 'Michajlovitj', 'Bacharev', 'Bakharev', 'Mikhailovici'}                100                    100.00                1.00              3              match    0.706188        0.145989          0.147823
# 54   13406                                                                                                                                         {'Hamu', 'Hamo', 'Al', 'Ahmad'}                                                                                                           {'Aljawadi', 'Saqr', 'Ahmad', 'Saqar', 'Hamdan', 'Jadawi', 'Ahmed', 'Salem', 'Salim', 'Al', 'Jaddawi'}                 85                     91.00                0.75              2  preliminary match    0.176406        0.200351          0.623244
# 55   13436                                                                                                                  {'Banza', 'Tambo', 'Numba', 'Ntambo', 'John', 'Numbi'}                                                                                                                                                                    {'Banza', 'Tambo', 'Ntambo', 'John', 'Numbi'}                 96                     95.00                1.00              4              match    0.703087        0.145624          0.151289
# 56   13440                                                                             {'Magomedovich', 'Muhammad', 'Aselderov', 'Muhamadmuhtar', 'Abu', 'Kadari', 'Rustam', 'Al'}                                                                     {'Magomedovich', 'Mukhammad', 'Asel', 'Muhammad', 'Derov', 'Aselderov', 'Muhamadmuhtar', 'Abu', 'Kadari', 'Mukhamadmukhtar', 'Rustam', 'Al'}                 98                     96.75                1.00              8              match    0.699496        0.146657          0.153848
# 57   13454                                                                                                                                                   {'Ri', 'Su', 'Myong'}                                                                                                                                                                              {'Ri', 'Myong', 'Su', 'Rimyeongsu'}                 92                     89.67                1.00              3              match    0.696485        0.155463          0.148052
# 58   13456                                                                                                                                                 {'Wang', 'Uk', 'Chang'}                                                                                                                                                                            {'Uk', 'Wangcangug', 'Chang', 'Wang'}                 94                     92.33                1.00              3              match    0.704780        0.146339          0.148882
# 59   13515                                                                       {'Muhammad', 'Rayan', 'Aisyah', 'Tamtomo', 'Bahrum', 'Rayyan', 'Bahrun', 'Anggih', 'Abu', 'Naim'}                                                                                                                {'Muhammad', 'Aisyah', 'Rayyan', 'Tamtomo', 'Rayan', 'Bahrum', 'Bahrun', 'Anggih', 'Abu', 'Naim'}                 98                     97.12                1.00              8              match    0.703128        0.145473          0.151399
# 60   13562                                                                                                                                     {'Kim', 'Ng', 'Il', 'Kyo', 'Kyong'}                                                                                                                                                                              {'Kim', 'Ng', 'Il', 'Kyo', 'Kyong'}                 90                     87.00                1.00              4              match    0.678065        0.176005          0.145929
# 61   13564                                                                                                                                   {'Chol', 'Man', 'Ko', 'L', 'Ch', 'O'}                                                                                                                                                                            {'Chol', 'Man', 'Ko', 'L', 'Ch', 'O'}                 91                     88.33                1.00              6              match    0.691913        0.160968          0.147119
# 62   13570                                                                                                                                      {'Chun', 'Ri', 'Un', 'Hwan', 'Ch'}                                                                                                                                                                               {'Chun', 'Ri', 'Un', 'Hwan', 'Ch'}                 93                     90.20                1.00              5              match    0.703375        0.147511          0.149114
# 63   13574                                                                                                                       {'U', 'So', 'Song', 'Eun', 'Ri', 'Un', 'Ng', 'N'}                                                                                                                                                                {'U', 'So', 'Song', 'Eun', 'Ri', 'Un', 'Ng', 'N'}                 91                     88.00                1.00              8              match    0.680530        0.174535          0.144935
# 64   13619                                                                                                                    {'Abubakar', 'Abdifatah', 'Musa', 'Abdi', 'Muhajir'}                                                                                                                                                             {'Abubakar', 'Abdifatah', 'Musa', 'Abdi', 'Muhajir'}                 98                     98.00                1.00              5              match    0.705942        0.145774          0.148284
# 65   13675                                                                                            {'Koshlaf', 'Keslaf', 'Amin', 'Qasab', 'Arabi', 'Mohammed', 'Al', 'Kashlaf'}                                                                                                                                     {'Koshlaf', 'Keslaf', 'Amin', 'Qasab', 'Arabi', 'Mohammed', 'Al', 'Kashlaf'}                 96                     95.33                1.00              6              match    0.705574        0.145979          0.148447
# 66   13676                                                           {'Milad', 'Rahman', 'Abdulrahman', 'Bija', 'Abd', 'Abdurahman', 'Ibrahim', 'Salem', 'Salim', 'Al', 'Kashlaf'}                                                                                                                                                                {'Milad', 'Rahman', 'Bija', 'Abd', 'Salim', 'Al'}                 89                     93.17                0.75              6  preliminary match    0.352796        0.181788          0.465416
# 67   13697                                                                                                                                     {'Abu', 'Tahari', 'Musab', 'Rabah'}                                                                                                                                                                              {'Abu', 'Musab', 'Tahari', 'Rabah'}                 96                     94.25                1.00              4              match    0.704300        0.145875          0.149824
# 68   13725                                                                                                                            {'Denis', 'Miroshnitchenko', 'Nikolaevitch'}                                                                                                                                     {'Denis', 'Mirosjnitjenko', 'Nikolaevich', 'Nikolajevitj', 'Miroshnichenko'}                 98                     98.33                0.97              3              match    0.706421        0.145873          0.147706
# 69   13734                                                                                                                                                        {'Tun', 'Naing'}                                                                                                                                                                                                 {'Tun', 'Naing'}                 85                     91.00                1.00              2  preliminary match    0.161129        0.163290          0.675580
# 70   13806                                                                                                                                    {'Basova', 'Lidia', 'Aleksandrovna'}                                                                                                                              {'Oleksandrivna', 'Lidiya', 'Basova', 'Lidia', 'Aleksandrovna', 'Lydyja', 'Lidija'}                 99                     98.33                1.00              3              match    0.706475        0.145884          0.147640
# 71   13810                                                                                                                                {'Vladimirovich', 'Nemtsev', 'Vladimir'}                                                                                               {'Vladimirovich', 'Nemtsev', 'Volodymyrovych', 'Volodymyr', 'Vladimir', 'Volodimirovich', 'Niemtsev', 'Volodimir'}                 85                    100.00                1.00              2  preliminary match    0.394454        0.171527          0.434019
# 72   13815                                                                                                                                 {'Burhaneddine', 'Mahir', 'Iman', 'Al'}                                                                             {'Daour', 'Imad', 'Ben', 'Imed', 'Zrqwy', 'Mekki', 'Zarga', 'Mky', 'Nadre', 'Akhdar', 'Md', 'Zarkaoui', 'Bn', 'Dour', 'Nadra', 'Al'}                 74                     79.12                0.60              2          not match    0.161924        0.671392          0.166684
# 73   13880                                                                                                                                                 {'Droganov', 'Aleksei'}                                                                                                                                      {'Anatoljevitj', 'Anatolyevich', 'Andrej', 'Alekhin', 'Aljochin', 'Andrei'}                 50                     71.43                0.60              1          not match    0.157783        0.681862          0.160355
# 74   13888                                                                                                                                {'Mohammad', 'Alotaibi', 'Al', 'Otaibi'}                                                                                                             {'Mhmd', 'Muhammad', 'Mohamed', 'Mufleh', 'Mflh', 'Mohammad', 'Muhamad', 'Mohammed', 'Al', 'Muflih'}                 85                     93.50                0.75              2  preliminary match    0.182685        0.180019          0.637297
# 75   13896                                                                                                               {'Almuslih', 'Musleh', 'Shaya', 'Muflih', 'Al', 'Mufleh'}                                                                                                             {'Mhmd', 'Muhammad', 'Mohamed', 'Mufleh', 'Mflh', 'Mohammad', 'Muhamad', 'Mohammed', 'Al', 'Muflih'}                 85                     93.50                0.60              2  preliminary match    0.194325        0.294711          0.510964
# 76   13933                                                                                             {'Khomenko', 'Khamenka', 'Nikolaevich', 'Siarhei', 'Mikalaevich', 'Sergei'}                                              {'Mikalajevitj', 'Khomenko', 'Chamenka', 'Siarhej', 'Khamenka', 'Nikolaevich', 'Nikolajevitj', 'Siargei', 'Siarhei', 'Mikalaevich', 'Chomenko', 'Sergej', 'Sergei'}                100                    100.00                1.00              4              match    0.664685        0.149536          0.185779
# 77   13951                                         {'Aleksandr', 'Vladimirovich', 'Kanyuk', 'Vladzimirovich', 'Alyaksandr', 'Alexander', 'Aliaksandr', 'Konyuk', 'Uladzimiravich'}                                    {'Kanyuk', 'Vladimirovich', 'Konjuk', 'Kanjuk', 'Aljaksandr', 'Alexander', 'Aliaksandr', 'Uladzimiravitj', 'Konyuk', 'Uladzimiravich', 'Kaniuk', 'Vladimirovitj', 'Alexandr'}                100                    100.00                1.00              4              match    0.666127        0.149860          0.184013
# 78   13977                                                                                                                           {'Mshaweh', 'Mouchaweh', 'Lubana', 'Loubana'}                                                                                                                            {'Mshaweh', 'Lubanah', 'Lubana', 'Mshwh', 'Mushaweh', 'Mshawweh', 'Mushawweh', 'Lbn'}                 85                    100.00                1.00              2  preliminary match    0.279636        0.189165          0.531199
# 79   13981                                                                                                                                     {'Kinan', 'Yagi', 'Kenan', 'Yaghi'}                                                                                                                                                                {'Kinan', 'Yagi', 'Ygy', 'Yaghi', 'Kenan', 'Knn'}                 85                     95.00                1.00              2  preliminary match    0.194707        0.164464          0.640829
# 80   13989                                                                                                          {'Yakovlevich', 'Azemsha', 'Siarhei', 'Yakaulevich', 'Sergei'}                                                           {'Jakaulevitj', 'Siarhej', 'Iakaulevich', 'Azemsja', 'Jakovlevitj', 'Yakovlevich', 'Siargei', 'Azemsha', 'Siarhei', 'Yakaulevich', 'Sergej', 'Sergei'}                100                    100.00                1.00              4              match    0.697740        0.148338          0.153923
# 81   13992                                                                                                      {'Buzovski', 'Igor', 'Ivanovich', 'Ihar', 'Ivanavich', 'Buzouski'}                                                                                                {'Buzovski', 'Buzovskij', 'Igar', 'Ivanovitj', 'Igor', 'Ivanovich', 'Ihar', 'Ivanavitj', 'Ivanavich', 'Buzouski'}                 98                     97.50                1.00              4              match    0.704037        0.145381          0.150583
# 82   13994                                                                                                 {'Zubkov', 'Yevgenevich', 'Yaugenavich', 'Zubkou', 'Siarhei', 'Sergei'}                                                            {'Jauhenavitj', 'Jevgenjevitj', 'Zubkov', 'Siarhej', 'Yevgenevich', 'Iaugenavich', 'Yaugenavich', 'Siargei', 'Zubkou', 'Siarhei', 'Sergej', 'Sergei'}                100                    100.00                1.00              4              match    0.697740        0.148338          0.153923
# 83   13996                                                                                                            {'Pyotr', 'Petr', 'Piatrovich', 'Petrovich', 'Miklashevich'}                                                                                        {'Pyotr', 'Petr', 'Pjatrovitj', 'Piotr', 'Pjotr', 'Miklasjevitj', 'Piatrovich', 'Petrovich', 'Petrovitj', 'Miklashevich'}                 98                     97.50                1.00              4              match    0.704037        0.145381          0.150583
# 84   14013                                                                                                                                       {'Khan', 'Rao', 'Ahmed', 'Anwar'}                                                                                                                                                                            {'Motaqi', 'Amir', 'Khan', 'Muttaqi'}                 50                     95.00                0.50              1          not match    0.162503        0.665155          0.172342
# 85   14022                                                                                                          {'Dedkova', 'Natalia', 'Dziadkova', 'Natallia', 'Anatolievna'}                                                                            {'Euna', 'Dedkova', 'Anatoljevna', 'Natallja', 'Natalia', 'Anatoljeuna', 'Natalja', 'Dziadkova', 'Anatol', 'Natallia', 'Anatolievna'}                100                    100.00                1.00              3              match    0.706475        0.145884          0.147640
# 86   14036                                                                                                            {'Gennady', 'Andreievich', 'Genadz', 'Bogdan', 'Andreevich'}                                                                                                                                                     {'Gennady', 'Andreievich', 'Genadz', 'Bogdan', 'Andreevich'}                100                    100.00                1.00              3              match    0.705808        0.145746          0.148446
# 87   14071                                                                                                                                     {'Malek', 'Alia', 'Aliaa', 'Malik'}                                                                                                                                                                           {'Ly', 'Mlk', 'Malik', 'Malek', 'Ali'}                 85                     84.79                0.93              2  preliminary match    0.202000        0.269051          0.528949
# 88   14102                                                                                                                                    {'Tony', 'Gupta', 'Kumar', 'Rajesh'}                                                                                                                                                                               {'Tong', 'Gimdongun', 'Un', 'Kim'}                 50                     71.25                0.50              1          not match    0.153614        0.686392          0.159994
# ...
# 170  15784                                                                                                                                  {'Sergey', 'Nikolaevich', 'Menshikov'}                                                                                                                                                {'Nikolaevich', 'Stankevich', 'Sergey', 'Nikolayevich', 'Sergei'}                 85                    100.00                0.75              2  preliminary match    0.250900        0.170882          0.578218
# 171  15785                                                                                                                                  {'Elena', 'Mihaylova', 'Vladimirovna'}                                                                                                 {'Vladimirovich', 'Mikhailov', 'Sergej', 'Michajlov', 'Sergey', 'Serguei', 'Vladimirovic', 'Mihajlov', 'Sergei'}                 82                     84.93                0.75              2          not match    0.193273        0.590480          0.216246
# 172  15825                                                                                        {'Aleksander', 'Aleksandr', 'Popov', 'Nikolaevich', 'Alexander', 'Nikolayevich'}                                                                               {'Mokhorev', 'Aljaksandr', 'Mohorau', 'Nikolaevich', 'Alexander', 'Mochorev', 'Aliaksandr', 'Mikalaevich', 'Mokhorau', 'Mochorau'}                 95                     95.58                0.95              3              match    0.697552        0.154069          0.148379
# 173  15829                                                                                                 {'Vladmimirovich', 'Vladimirovich', 'Vladimir', 'Artyakov', 'Artjakov'}                                                                                                                             {'Aleksandr', 'Vladimirovich', 'Iltiakov', 'Alexander', 'Vladimirovitj', 'Iltyakov'}                 85                     87.50                0.88              2  preliminary match    0.226058        0.318650          0.455292
# 174  15843                                                                                                    {'Oleg', 'Nikolaevich', 'Yevtushenko', 'Nikolayevich', 'Evtushenko'}                                                                                                                                                {'Jepifanova', 'Nikolajevna', 'Nikolayevna', 'Epifanova', 'Olga'}                 76                     76.71                0.75              2          not match    0.169150        0.606933          0.223917
# 175  15881                                                                                                     {'Vladimirovich', 'Yevtushenkov', 'Evtushenkov', 'Feliks', 'Felix'}                                                                                                                                                         {'Petrovich', 'Yevtushenkov', 'Vladimir', 'Evtushenkov'}                 85                     88.10                0.75              2  preliminary match    0.196963        0.351068          0.451969
# 176  15895                                                                                                                                       {'Rajab', 'Maulawi', 'Salahudin'}                                                                                                                                                                                {'Rajab', 'Maulawi', 'Salahudin'}                 99                     98.33                1.00              3              match    0.706238        0.145835          0.147927
# 177  15929                                                                                                                               {'Denisov', 'Vladimirovich', 'Alexander'}                                                                         {'Denis', 'Pusjilin', 'Pusjylin', 'Vladimirovich', 'Volodymyrovych', 'Denys', 'Volodomyrovytj', 'Pushylin', 'Vladimirovitj', 'Pushilin'}                 85                     89.58                0.75              2  preliminary match    0.193111        0.304628          0.502261
# 178  15934                                                                                                                                   {'Vasilyevich', 'Tonkovidov', 'Igor'}                                                                                                                                                                            {'Vasilyevich', 'Tonkovidov', 'Igor'}                 99                     98.33                1.00              3              match    0.706238        0.145835          0.147927
# 179  15986                                                                                                                                                     {'Piri', 'Morteza'}                                                                                                                                                                                              {'Piri', 'Morteza'}                 85                     97.50                1.00              2  preliminary match    0.158119        0.152074          0.689807
# 180  16081                                                                                         {'Mentos', 'Weldon', 'Vadym', 'Firdavysovych', 'Vasm', 'Vadim', 'Valiakhmetov'}                                                                                                                                                          {'Matafonov', 'Viktorovich', 'Viktorovitj', 'Vladimir'}                 50                     76.92                0.50              1          not match    0.164075        0.676708          0.159217
# 181  16224                                                                        {'Karim', 'Ahmad', 'Salih', 'Muhammad', 'Abd', 'Akram', 'Ajuri', 'Ajouri', 'Abu', 'Al', 'Hasan'}                                                                                          {'Hassan', 'Muhammad', 'Sabawi', 'Aiman', 'Awi', 'Ayman', 'Salman', 'Ibrahim', 'Qais', 'Sab', 'Tikriti', 'Al', 'Hasan'}                 86                     94.00                0.60              3  preliminary match    0.227448        0.264748          0.507804
# 182  16230                                                                                                                                               {'Rida', 'Ali', 'Khamis'}                                                                                                                                                                                {'Rida', 'Ali', 'Reda', 'Khamis'}                 96                     94.00                1.00              3              match    0.704613        0.145940          0.149447
# 183  16235                                                                                                                                   {'Bychkov', 'Nikolaevich', 'Mikhail'}                                                                                      {'Nikolajewitsch', 'Mikhail', 'Nikolajewicz', 'Bielousow', 'Nikolaevich', 'Nikolajevitj', 'Belusow', 'Belousov', 'Michail'}                 85                    100.00                0.75              2  preliminary match    0.306521        0.180548          0.512931
# 184  16312                                                                                                                                                       {'Salehi', 'Ali'}                                                                                                                          {'Mohamed', 'Abdullah', 'Masri', 'Mariam', 'El', 'Saleh', 'Abu', 'Alfi', 'Ahmed', 'Al'}                 85                     83.90                0.88              2  preliminary match    0.202436        0.270916          0.526649
# 185  16319                                                                        {'Jirjis', 'Boutros', 'Hallaq', 'Gerges', 'George', 'Bin', 'Girgus', 'Gorgeous', 'Al', 'Butrus'}                                                                                                                                                                      {'Boutros', 'Hallaq', 'Btrs', 'Lhlq', 'Al'}                 87                     95.67                0.60              3  preliminary match    0.262333        0.260930          0.476737
# 186  16322                                                                                                                                          {'Abdel', 'Jokhadar', 'Qader'}                                                                                                                                                                               {'Abdul', 'Hai', 'Hazem', 'Qader'}                 83                     85.50                0.75              2          not match    0.174714        0.509692          0.315595
# 187  16352                                                                                                                                                    {'Ali', 'Esfanjani'}                                                                                                                          {'Mohamed', 'Abdullah', 'Masri', 'Mariam', 'El', 'Saleh', 'Abu', 'Alfi', 'Ahmed', 'Al'}                 50                     81.43                0.60              1          not match    0.160762        0.676321          0.162917
# 188  16378                                                                                                                              {'Golyakov', 'Vladimirovich', 'Aleksandr'}                                                                                      {'Aleksandr', 'Golakov', 'Vladimirovich', 'Goljakov', 'Alexander', 'Golyakov', 'Vladimirovits', 'Vladimirovic', 'Alexandr'}                100                    100.00                1.00              3              match    0.706188        0.145989          0.147823
# 189  16448                                                                                                                                {'Vyacheslavovich', 'Karpushin', 'Oleg'}                                                                                                                                                        {'Vjatjeslavovitj', 'Oleg', 'Viacheslavovich', 'Dadonov'}                 85                     96.50                0.75              2  preliminary match    0.185684        0.166904          0.647412
# 190  16454                                                                                                                                        {'Irina', 'Vernerovna', 'Gaida'}                                                                                                                                        {'Rukavisjnikova', 'Valerjevna', 'Rukavishnikova', 'Valeryevna', 'Irina'}                 81                     83.55                0.75              2          not match    0.165160        0.619470          0.215370
# 191  16459                                                                                                                                          {'Ayash', 'Ayyash', 'Mustafa'}                                                                                                                                                  {'Houda', 'Mahdi', 'Ammach', 'Ammash', 'Salih', 'Huda', 'Sali'}                 50                     72.73                0.60              1          not match    0.153909        0.686153          0.159938
# 192  16491                                                                                                                                           {'Kitutu', 'Goretti', 'Mary'}                                                                                                                                               {'Malyj', 'Georgievich', 'Pavel', 'Malyi', 'Maly', 'Georgijevitj'}                 50                     71.25                0.50              1          not match    0.153909        0.686153          0.159938
# 193  16594                                                                                                            {'Gennadyevich', 'Biba', 'Gennadievich', 'Vadim', 'Pogodin'}                                                     {'Volodymyr', 'Gennadjevitj', 'Vladimir', 'Genadiiovich', 'Volodimir', 'Pakreiev', 'Gennadievich', 'Pakrejev', 'Pakreev', 'Henadijovytj', 'Gennad', 'Evich'}                 81                     88.46                0.60              2          not match    0.177877        0.643958          0.178165
# 194  16604                                                                                                                                                     {'Vahedi', 'Hamid'}                                                                                                                                                                                              {'Vahedi', 'Hamid'}                 85                     97.50                1.00              2  preliminary match    0.157812        0.153718          0.688469
# 195  16669                                                                                                                     {'Sergeevich', 'Aleksandr', 'Kuznetsov', 'Ratibor'}                                                                                                                                             {'Aleksandr', 'Kuznetsov', 'Alexander', 'Sergeevich', 'Sergejevitj'}                 94                    100.00                0.75              3              match    0.599895        0.208789          0.191317
# 196  16748                                                                                                          {'Bolshakov', 'Aleksandr', 'Sergeyevich', 'Aaelbas', 'Wtlfnt'}                                                                                                                                           {'Aleksandr', 'Aksyonenko', 'Aksionenko', 'Sergeevich', 'Sergejevitj'}                 85                     99.05                0.60              2  preliminary match    0.279928        0.351937          0.368135
# 197  16811                                                                                                                                {'Dinara', 'Mustafaeva', 'Dzhamilievna'}                                                                                                                                              {'Darya', 'Vasilievna', 'Vasiljevna', 'Darja', 'Daria', 'Morozova'}                 69                     72.00                0.60              2          not match    0.155248        0.680969          0.163782
# 198  16813                                                                                                                                                  {'Mutlu', 'Cobanoglu'}                                                                                                                                                                         {'Abdul', 'Majeed', 'Majid', 'Chaudhry'}                 12                      0.00                0.50              0          not match    0.154203        0.685561          0.160236
# 199  16814                                                                                                                      {'Valentinovna', 'Khomenko', 'Tatiana', 'Tatyana'}                                                                                                                                                                  {'Rachid', 'Kathim', 'Kazim', 'Taan', 'Rashid'}                 50                     69.09                0.50              1          not match    0.153614        0.686392          0.159994

# %%
#store uk ids of incorrectly labelled rows
change_to_match_2=[11039,13676,13810,14637]
change_to_not_match_2=[13888,14742,16224]
change_to_preliminary_match_2=[]

# %%
#create new column for human assigned labels by replacing the incorrect labels 
df_review_2['Human-assigned Label 2']=df_review_2['Predicted Label 2']

df_review_2.loc[df_review_2['uk_id'].isin(change_to_not_match_2), 'Human-assigned Label 2']='not match'
df_review_2.loc[df_review_2['uk_id'].isin(change_to_preliminary_match_2), 'Human-assigned Label 2']='preliminary match'
df_review_2.loc[df_review_2['uk_id'].isin(change_to_match_2), 'Human-assigned Label 2']='match'

# %%
#create classification report
report_review_2=classification_report(    
    df_review_2['Human-assigned Label 2'],
    df_review_2['Predicted Label 2'],
    labels=class_labels,
    output_dict=True
)

#create confusion matrix
confusion_matrix_r_2=confusion_matrix(df_review_2['Human-assigned Label 2'], df_review_2['Predicted Label 2'],labels=class_labels)

#store relevant metrics
precision_match_r_2=report_review_2['match']['precision']
precision_not_match_r_2=report_review_2['not match']['precision']
recall_not_match_r_2=report_review_2['not match']['recall']


#print results
print(confusion_matrix_r_2)


print("\nClassification Report Summary:")
print(f"'Match' Precision:     {precision_match_r_2}")
print(f"'Not Match' Precision: {precision_not_match_r_2}")
print(f"'Not Match' Recall:    {recall_not_match_r_2}")
# Out:
# [[ 31   3   0]
#  [  0  36   0]
#  [  0   4 126]]
#
# Classification Report Summary:
# 'Match' Precision:     1.0
# 'Not Match' Precision: 1.0
# 'Not Match' Recall:    0.9117647058823529

# %%
#display value counts for each precited class
df_predicted_2['Predicted Label 2'].value_counts()
# Out:
# Predicted Label 2
# match                1991
# preliminary match     641
# not match             391
# Name: count, dtype: int64
